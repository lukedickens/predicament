# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
import scipy as sp
import scipy.stats
import pandas as pd
import numpy as np
from tqdm import tqdm
import itertools
import re
res_digit = r'[0-9]'

# fourier transform
from scipy.fft import fft, ifft

from sklearn.metrics import classification_report
from sklearn.svm import SVC

import matplotlib.pyplot as plt

# %%
# This is a hack to make the library in the parent folder available for imoprts
# A better solution is by np8 here:
# https://stackoverflow.com/questions/714063/importing-modules-from-parent-folder
import sys
import os
import inspect

thisdir = sys.path[0]
print(f"thisdir = {thisdir}")
parentdir = os.path.dirname(thisdir)
#print(f"parentdir = {parentdir}")
if not parentdir in sys.path:
    print("Adding parent directory to python path")
    sys.path.insert(1, parentdir)
else:
    print("Skipping adding parent direct to path (there already)")

print(f"sys.path =\n{sys.path}")
# Out:
# thisdir = /home/luke/git/external/predicament/notebooks
# Adding parent directory to python path
# sys.path =
# ['/home/luke/git/external/predicament/notebooks', '/home/luke/git/external/predicament', '/usr/lib/python310.zip', '/usr/lib/python3.10', '/usr/lib/python3.10/lib-dynload', '', '/home/luke/.local/lib/python3.10/site-packages', '/usr/local/lib/python3.10/dist-packages', '/usr/lib/python3/dist-packages', '/usr/lib/python3.10/dist-packages']

# %%
## ensure relative path to data directory is sound
# for the notebook we need to modify the BASE_DATA_FOLDER
import os 
os.environ['PREDICAMENT_DATA_DIR'] =  '../data'

from predicament.utils.config import FEATURED_BASE_PATH

# %%
from predicament.utils.file_utils import load_dataframe_and_config

from predicament.evaluation.balancing import get_group_label_counts
from predicament.evaluation.balancing import balance_data
from predicament.evaluation.grouping import get_group_assignments
from predicament.evaluation.staging import get_design_matrix
from predicament.evaluation.results import output_model_best_from_results
from predicament.evaluation.results import save_results_df_to_file

# %% [markdown]
# ## Load features
#
# Before running this, you will need to generate featured data. See README file for details. For the variable `subdir` below replace this with the subdirectory name of the featured data.

# %%
subdir = 'dreem_10secs'
featured_data_dir = os.path.join(FEATURED_BASE_PATH,subdir)

featured_df, featured_config = load_dataframe_and_config(
    featured_data_dir, 'featured.csv')
n_channels = int(featured_config['LOAD']['n_channels'])
channels = json.loads(featured_config['LOAD']['channels'].replace("'",'"'))
participant_list = json.loads(featured_config['LOAD']['participant_list'].replace("'",'"'))
Fs = int(featured_config['LOAD']['sample_rate'])
window_size = int(featured_config['LOAD']['window_size'])
time = window_size/Fs
print(f"Fs: {Fs}, n_samples = {window_size}, time: {time}s, n_channels: {n_channels}")
# Out:
# Fs: 64, n_samples = 256, time: 4.0s, n_channels: 7

# %%
featured_df.columns
# Out:
# Index(['participant', 'condition', 'start time', 'Mean0', 'Mean1', 'Mean2',
#        'Mean3', 'Mean4', 'Mean5', 'Mean6',
#        ...
#        'FreqKurtosis4', 'FreqKurtosis5', 'FreqKurtosis6',
#        'LempelZivEntropy[b=1][0]', 'LempelZivEntropy[b=1][1]',
#        'LempelZivEntropy[b=1][2]', 'LempelZivEntropy[b=1][3]',
#        'LempelZivEntropy[b=1][4]', 'LempelZivEntropy[b=1][5]',
#        'LempelZivEntropy[b=1][6]'],
#       dtype='object', length=157)

# %%
is_balanced = True
if is_balanced:
    # balance featured data
    subject_condition_counts = get_group_label_counts(featured_df, 'participant', 'condition')
    print(f"before balancing: subject_condition_counts = {subject_condition_counts}")
    featured_df = balance_data(featured_df, group_col='participant', label_col='condition')
    subject_condition_counts = get_group_label_counts(featured_df, 'participant', 'condition')

    print(f"after balancing: subject_condition_counts = {subject_condition_counts}")
# Out:
# before balancing: subject_condition_counts = [[ 833.  473.  473.  473.  473.]
#  [ 833.  113.  353.  473.  353.]
#  [ 833.  233.  473.  473.  473.]
#  [ 833.  593.  353.  233.  473.]
#  [   0.  113.    0. 1073.  353.]
#  [ 853.  433.    0.  517.  373.]
#  [ 833.  593.  473.  353.   89.]
#  [ 833.  593.    0.  353.  353.]
#  [ 823.  333.    0.  565.  357.]
#  [ 953.  473.  353.  473.  353.]
#  [ 713.  593.  473.  353.  473.]]
# after balancing: subject_condition_counts = [[296. 312. 473. 272. 287.]
#  [296. 113. 353. 272. 287.]
#  [296. 233. 473. 272. 287.]
#  [296. 312. 353. 233. 287.]
#  [  0. 113.   0. 272. 287.]
#  [296. 312.   0. 272. 287.]
#  [296. 312. 473. 272.  89.]
#  [296. 312.   0. 272. 287.]
#  [296. 312.   0. 272. 287.]
#  [296. 312. 353. 272. 287.]
#  [296. 312. 473. 272. 287.]]

# %% [markdown]
# ## Prepare Parameter Search Experiment

# %%
import pandas as pd

from sklearn.svm import SVC
from sklearn.model_selection import RandomizedSearchCV 
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import GroupKFold
from skopt import BayesSearchCV
# parameter ranges are specified by one of below
from skopt.space import Real, Categorical, Integer

# %%
# model name
name = 'SVC'

# extract input data
feature_types, feature_names, designmtx = get_design_matrix(featured_df)
# extract labels
condition_data = featured_df['condition'].values.astype(int)

# prepare Hold one group out cross validation
held_out = 'participant'
held_out, groups, group_assignments = get_group_assignments(featured_df)
n_groups = len(groups)
# cross validation splits    
group_kfold = GroupKFold(n_splits=n_groups)

# choose which search to perform
# search_type = 'random_search'
search_type = 'bayesian_optimization'
# number of iterations for your search
n_iter = 50
# Out:
# feature_type_pairs = [('participant', 'participant'), ('condition', 'condition'), ('start time', 'start'), ('Mean0', 'Mean'), ('Mean1', 'Mean'), ('Mean2', 'Mean'), ('Mean3', 'Mean'), ('Mean4', 'Mean'), ('Mean5', 'Mean'), ('Mean6', 'Mean'), ('SD0', 'SD'), ('SD1', 'SD'), ('SD2', 'SD'), ('SD3', 'SD'), ('SD4', 'SD'), ('SD5', 'SD'), ('SD6', 'SD'), ('MAD0', 'MAD'), ('MAD1', 'MAD'), ('MAD2', 'MAD'), ('MAD3', 'MAD'), ('MAD4', 'MAD'), ('MAD5', 'MAD'), ('MAD6', 'MAD'), ('Max0', 'Max'), ('Max1', 'Max'), ('Max2', 'Max'), ('Max3', 'Max'), ('Max4', 'Max'), ('Max5', 'Max'), ('Max6', 'Max'), ('Min0', 'Min'), ('Min1', 'Min'), ('Min2', 'Min'), ('Min3', 'Min'), ('Min4', 'Min'), ('Min5', 'Min'), ('Min6', 'Min'), ('Energy0', 'Energy'), ('Energy1', 'Energy'), ('Energy2', 'Energy'), ('Energy3', 'Energy'), ('Energy4', 'Energy'), ('Energy5', 'Energy'), ('Energy6', 'Energy'), ('IQR0', 'IQR'), ('IQR1', 'IQR'), ('IQR2', 'IQR'), ('IQR3', 'IQR'), ('IQR4', 'IQR'), ('IQR5', 'IQR'), ('IQR6', 'IQR'), ('Correlation0', 'Correlation'), ('Correlation1', 'Correlation'), ('Correlation2', 'Correlation'), ('Correlation3', 'Correlation'), ('Correlation4', 'Correlation'), ('Correlation5', 'Correlation'), ('Correlation6', 'Correlation'), ('Correlation7', 'Correlation'), ('Correlation8', 'Correlation'), ('Correlation9', 'Correlation'), ('Correlation10', 'Correlation'), ('Correlation11', 'Correlation'), ('Correlation12', 'Correlation'), ('Correlation13', 'Correlation'), ('Correlation14', 'Correlation'), ('Correlation15', 'Correlation'), ('Correlation16', 'Correlation'), ('Correlation17', 'Correlation'), ('Correlation18', 'Correlation'), ('Correlation19', 'Correlation'), ('Correlation20', 'Correlation'), ('arCoeff0', 'arCoeff'), ('arCoeff1', 'arCoeff'), ('arCoeff2', 'arCoeff'), ('arCoeff3', 'arCoeff'), ('arCoeff4', 'arCoeff'), ('arCoeff5', 'arCoeff'), ('arCoeff6', 'arCoeff'), ('arCoeff7', 'arCoeff'), ('arCoeff8', 'arCoeff'), ('arCoeff9', 'arCoeff'), ('arCoeff10', 'arCoeff'), ('arCoeff11', 'arCoeff'), ('arCoeff12', 'arCoeff'), ('arCoeff13', 'arCoeff'), ('arCoeff14', 'arCoeff'), ('arCoeff15', 'arCoeff'), ('arCoeff16', 'arCoeff'), ('arCoeff17', 'arCoeff'), ('arCoeff18', 'arCoeff'), ('arCoeff19', 'arCoeff'), ('arCoeff20', 'arCoeff'), ('arCoeff21', 'arCoeff'), ('arCoeff22', 'arCoeff'), ('arCoeff23', 'arCoeff'), ('arCoeff24', 'arCoeff'), ('arCoeff25', 'arCoeff'), ('arCoeff26', 'arCoeff'), ('arCoeff27', 'arCoeff'), ('Hurst_H0', 'Hurst'), ('Hurst_H1', 'Hurst'), ('Hurst_H2', 'Hurst'), ('Hurst_H3', 'Hurst'), ('Hurst_H4', 'Hurst'), ('Hurst_H5', 'Hurst'), ('Hurst_H6', 'Hurst'), ('Hurst_C0', 'Hurst'), ('Hurst_C1', 'Hurst'), ('Hurst_C2', 'Hurst'), ('Hurst_C3', 'Hurst'), ('Hurst_C4', 'Hurst'), ('Hurst_C5', 'Hurst'), ('Hurst_C6', 'Hurst'), ('LyapunovExponent0', 'LyapunovExponent'), ('LyapunovExponent1', 'LyapunovExponent'), ('LyapunovExponent2', 'LyapunovExponent'), ('LyapunovExponent3', 'LyapunovExponent'), ('LyapunovExponent4', 'LyapunovExponent'), ('LyapunovExponent5', 'LyapunovExponent'), ('LyapunovExponent6', 'LyapunovExponent'), ('MaxFreqInd0', 'MaxFreqInd'), ('MaxFreqInd1', 'MaxFreqInd'), ('MaxFreqInd2', 'MaxFreqInd'), ('MaxFreqInd3', 'MaxFreqInd'), ('MaxFreqInd4', 'MaxFreqInd'), ('MaxFreqInd5', 'MaxFreqInd'), ('MaxFreqInd6', 'MaxFreqInd'), ('MeanFreq0', 'MeanFreq'), ('MeanFreq1', 'MeanFreq'), ('MeanFreq2', 'MeanFreq'), ('MeanFreq3', 'MeanFreq'), ('MeanFreq4', 'MeanFreq'), ('MeanFreq5', 'MeanFreq'), ('MeanFreq6', 'MeanFreq'), ('FreqSkewness0', 'FreqSkewness'), ('FreqSkewness1', 'FreqSkewness'), ('FreqSkewness2', 'FreqSkewness'), ('FreqSkewness3', 'FreqSkewness'), ('FreqSkewness4', 'FreqSkewness'), ('FreqSkewness5', 'FreqSkewness'), ('FreqSkewness6', 'FreqSkewness'), ('FreqKurtosis0', 'FreqKurtosis'), ('FreqKurtosis1', 'FreqKurtosis'), ('FreqKurtosis2', 'FreqKurtosis'), ('FreqKurtosis3', 'FreqKurtosis'), ('FreqKurtosis4', 'FreqKurtosis'), ('FreqKurtosis5', 'FreqKurtosis'), ('FreqKurtosis6', 'FreqKurtosis'), ('LempelZivEntropy[b=1][0]', 'LempelZivEntropy'), ('LempelZivEntropy[b=1][1]' ...
# feature_names = ['Mean0', 'Mean1', 'Mean2', 'Mean3', 'Mean4', 'Mean5', 'Mean6', 'SD0', 'SD1', 'SD2', 'SD3', 'SD4', 'SD5', 'SD6', 'MAD0', 'MAD1', 'MAD2', 'MAD3', 'MAD4', 'MAD5', 'MAD6', 'Max0', 'Max1', 'Max2', 'Max3', 'Max4', 'Max5', 'Max6', 'Min0', 'Min1', 'Min2', 'Min3', 'Min4', 'Min5', 'Min6', 'Energy0', 'Energy1', 'Energy2', 'Energy3', 'Energy4', 'Energy5', 'Energy6', 'IQR0', 'IQR1', 'IQR2', 'IQR3', 'IQR4', 'IQR5', 'IQR6', 'Correlation0', 'Correlation1', 'Correlation2', 'Correlation3', 'Correlation4', 'Correlation5', 'Correlation6', 'Correlation7', 'Correlation8', 'Correlation9', 'Correlation10', 'Correlation11', 'Correlation12', 'Correlation13', 'Correlation14', 'Correlation15', 'Correlation16', 'Correlation17', 'Correlation18', 'Correlation19', 'Correlation20', 'arCoeff0', 'arCoeff1', 'arCoeff2', 'arCoeff3', 'arCoeff4', 'arCoeff5', 'arCoeff6', 'arCoeff7', 'arCoeff8', 'arCoeff9', 'arCoeff10', 'arCoeff11', 'arCoeff12', 'arCoeff13', 'arCoeff14', 'arCoeff15', 'arCoeff16', 'arCoeff17', 'arCoeff18', 'arCoeff19', 'arCoeff20', 'arCoeff21', 'arCoeff22', 'arCoeff23', 'arCoeff24', 'arCoeff25', 'arCoeff26', 'arCoeff27', 'Hurst_H0', 'Hurst_H1', 'Hurst_H2', 'Hurst_H3', 'Hurst_H4', 'Hurst_H5', 'Hurst_H6', 'Hurst_C0', 'Hurst_C1', 'Hurst_C2', 'Hurst_C3', 'Hurst_C4', 'Hurst_C5', 'Hurst_C6', 'LyapunovExponent0', 'LyapunovExponent1', 'LyapunovExponent2', 'LyapunovExponent3', 'LyapunovExponent4', 'LyapunovExponent5', 'LyapunovExponent6', 'MaxFreqInd0', 'MaxFreqInd1', 'MaxFreqInd2', 'MaxFreqInd3', 'MaxFreqInd4', 'MaxFreqInd5', 'MaxFreqInd6', 'MeanFreq0', 'MeanFreq1', 'MeanFreq2', 'MeanFreq3', 'MeanFreq4', 'MeanFreq5', 'MeanFreq6', 'FreqSkewness0', 'FreqSkewness1', 'FreqSkewness2', 'FreqSkewness3', 'FreqSkewness4', 'FreqSkewness5', 'FreqSkewness6', 'FreqKurtosis0', 'FreqKurtosis1', 'FreqKurtosis2', 'FreqKurtosis3', 'FreqKurtosis4', 'FreqKurtosis5', 'FreqKurtosis6', 'LempelZivEntropy[b=1][0]', 'LempelZivEntropy[b=1][1]', 'LempelZivEntropy[b=1][2]', 'LempelZivEntropy[b=1][3]', 'LempelZivEntropy[b=1][4]', 'LempelZivEntropy[b=1][5]', 'LempelZivEntropy[b=1][6]']
# feature_type_pairs = [('participant', 'participant'), ('condition', 'condition'), ('start time', 'start'), ('Mean0', 'Mean'), ('Mean1', 'Mean'), ('Mean2', 'Mean'), ('Mean3', 'Mean'), ('Mean4', 'Mean'), ('Mean5', 'Mean'), ('Mean6', 'Mean'), ('SD0', 'SD'), ('SD1', 'SD'), ('SD2', 'SD'), ('SD3', 'SD'), ('SD4', 'SD'), ('SD5', 'SD'), ('SD6', 'SD'), ('MAD0', 'MAD'), ('MAD1', 'MAD'), ('MAD2', 'MAD'), ('MAD3', 'MAD'), ('MAD4', 'MAD'), ('MAD5', 'MAD'), ('MAD6', 'MAD'), ('Max0', 'Max'), ('Max1', 'Max'), ('Max2', 'Max'), ('Max3', 'Max'), ('Max4', 'Max'), ('Max5', 'Max'), ('Max6', 'Max'), ('Min0', 'Min'), ('Min1', 'Min'), ('Min2', 'Min'), ('Min3', 'Min'), ('Min4', 'Min'), ('Min5', 'Min'), ('Min6', 'Min'), ('Energy0', 'Energy'), ('Energy1', 'Energy'), ('Energy2', 'Energy'), ('Energy3', 'Energy'), ('Energy4', 'Energy'), ('Energy5', 'Energy'), ('Energy6', 'Energy'), ('IQR0', 'IQR'), ('IQR1', 'IQR'), ('IQR2', 'IQR'), ('IQR3', 'IQR'), ('IQR4', 'IQR'), ('IQR5', 'IQR'), ('IQR6', 'IQR'), ('Correlation0', 'Correlation'), ('Correlation1', 'Correlation'), ('Correlation2', 'Correlation'), ('Correlation3', 'Correlation'), ('Correlation4', 'Correlation'), ('Correlation5', 'Correlation'), ('Correlation6', 'Correlation'), ('Correlation7', 'Correlation'), ('Correlation8', 'Correlation'), ('Correlation9', 'Correlation'), ('Correlation10', 'Correlation'), ('Correlation11', 'Correlation'), ('Correlation12', 'Correlation'), ('Correlation13', 'Correlation'), ('Correlation14', 'Correlation'), ('Correlation15', 'Correlation'), ('Correlation16', 'Correlation'), ('Correlation17', 'Correlation'), ('Correlation18', 'Correlation'), ('Correlation19', 'Correlation'), ('Correlation20', 'Correlation'), ('arCoeff0', 'arCoeff'), ('arCoeff1', 'arCoeff'), ('arCoeff2', 'arCoeff'), ('arCoeff3', 'arCoeff'), ('arCoeff4', 'arCoeff'), ('arCoeff5', 'arCoeff'), ('arCoeff6', 'arCoeff'), ('arCoeff7', 'arCoeff'), ('arCoeff8', 'arCoeff'), ('arCoeff9', 'arCoeff'), ('arCoeff10', 'arCoeff'), ('arCoeff11', 'arCoeff'), ('arCoeff12', 'arCoeff'), ('arCoeff13', 'arCoeff'), ('arCoeff14', 'arCoeff'), ('arCoeff15', 'arCoeff'), ('arCoeff16', 'arCoeff'), ('arCoeff17', 'arCoeff'), ('arCoeff18', 'arCoeff'), ('arCoeff19', 'arCoeff'), ('arCoeff20', 'arCoeff'), ('arCoeff21', 'arCoeff'), ('arCoeff22', 'arCoeff'), ('arCoeff23', 'arCoeff'), ('arCoeff24', 'arCoeff'), ('arCoeff25', 'arCoeff'), ('arCoeff26', 'arCoeff'), ('arCoeff27', 'arCoeff'), ('Hurst_H0', 'Hurst'), ('Hurst_H1', 'Hurst'), ('Hurst_H2', 'Hurst'), ('Hurst_H3', 'Hurst'), ('Hurst_H4', 'Hurst'), ('Hurst_H5', 'Hurst'), ('Hurst_H6', 'Hurst'), ('Hurst_C0', 'Hurst'), ('Hurst_C1', 'Hurst'), ('Hurst_C2', 'Hurst'), ('Hurst_C3', 'Hurst'), ('Hurst_C4', 'Hurst'), ('Hurst_C5', 'Hurst'), ('Hurst_C6', 'Hurst'), ('LyapunovExponent0', 'LyapunovExponent'), ('LyapunovExponent1', 'LyapunovExponent'), ('LyapunovExponent2', 'LyapunovExponent'), ('LyapunovExponent3', 'LyapunovExponent'), ('LyapunovExponent4', 'LyapunovExponent'), ('LyapunovExponent5', 'LyapunovExponent'), ('LyapunovExponent6', 'LyapunovExponent'), ('MaxFreqInd0', 'MaxFreqInd'), ('MaxFreqInd1', 'MaxFreqInd'), ('MaxFreqInd2', 'MaxFreqInd'), ('MaxFreqInd3', 'MaxFreqInd'), ('MaxFreqInd4', 'MaxFreqInd'), ('MaxFreqInd5', 'MaxFreqInd'), ('MaxFreqInd6', 'MaxFreqInd'), ('MeanFreq0', 'MeanFreq'), ('MeanFreq1', 'MeanFreq'), ('MeanFreq2', 'MeanFreq'), ('MeanFreq3', 'MeanFreq'), ('MeanFreq4', 'MeanFreq'), ('MeanFreq5', 'MeanFreq'), ('MeanFreq6', 'MeanFreq'), ('FreqSkewness0', 'FreqSkewness'), ('FreqSkewness1', 'FreqSkewness'), ('FreqSkewness2', 'FreqSkewness'), ('FreqSkewness3', 'FreqSkewness'), ('FreqSkewness4', 'FreqSkewness'), ('FreqSkewness5', 'FreqSkewness'), ('FreqSkewness6', 'FreqSkewness'), ('FreqKurtosis0', 'FreqKurtosis'), ('FreqKurtosis1', 'FreqKurtosis'), ('FreqKurtosis2', 'FreqKurtosis'), ('FreqKurtosis3', 'FreqKurtosis'), ('FreqKurtosis4', 'FreqKurtosis'), ('FreqKurtosis5', 'FreqKurtosis'), ('FreqKurtosis6', 'FreqKurtosis'), ('LempelZivEntropy[b=1][0]', 'LempelZivEntropy'), ('LempelZivEntropy[b=1][1]' ...

# %% [markdown]
# ## Random Search
#
# If `search_type == 'random_search'`, we use a random grid to search for best hyperparameters

# %%
df = pd.DataFrame(np.random.random((4,5)))
df.to_numpy().var()
# Out:
# 0.10061353469596819

# %%
if search_type == 'random_search':
    # regularization - soft-margin
    Cs = np.logspace(-6,2,9)
    # Kernel
    kernels = ['rbf', 'sigmoid']
    # Kernel scale parameter
    feature_var = featured_df.iloc[4:].to_numpy().var()
    gammas = np.logspace(-1,1,11)/len(feature_names)/feature_var
    # Independent term in kernel function. It is only significant in ‘poly’ and ‘sigmoid’.
    coef0s = np.linspace(-1,1,11)
    # Whether to use the shrinking heuristic. See the User Guide.
    shrinkings = [True, False] 
    # probability = False
    # tol = 1e-3
    # class_weight = None
    # Create the random grid
    random_grid = {
        'C' : Cs,
        'kernel' : kernels,
        'gamma' : gammas,
        'coef0' : coef0s,
        'shrinking' : shrinkings}

    # First create the base model to tune
    estimator = SVC()
    # Random search of parameters, using 3 fold cross validation, 
    # search across 100 different combinations, and use all available cores
    param_search = RandomizedSearchCV(
        estimator = estimator,
        param_distributions = random_grid,
        n_iter = n_iter,
        cv=group_kfold,
        verbose=2,
        random_state=42,
        n_jobs = -1)

    # Fit the random search model
    _ = param_search.fit(X=designmtx, y=condition_data, groups=group_assignments)

# %% [markdown]
# ## Bayesian Optimisation
#
# If `search_type == 'bayesian_optimization'`, we use a Bayesian Optimisation search for best hyperparameters. Should be quicker and more effective than random search

# %%
# Bayesian optimisation

if search_type == 'bayesian_optimization':

    # this is just a naive initial guess at what will work
    # note that the log-uniform prior helps to focus on 
    # smaller values
    feature_var = featured_df.iloc[4:].to_numpy().var()

    search_spaces = dict(
        # regularization - soft-margin
        C = Real(1e-6, 1e2, prior='log-uniform'),
        # Kernel
        kernel = Categorical(['rbf', 'sigmoid']),
        # Kernel scale parameter
        gammas = Real(1e-6, 4, prior='log-uniform')
        # Independent term in kernel function. It is only significant in ‘poly’ and ‘sigmoid’.
        coef0 = Real(-1, 1),
        # Whether to use the shrinking heuristic. See the User Guide.
        shrinkings = Categorical([True, False])
        ## fixed default parameters
        # probability = False
        # tol = 1e-3
        # class_weight = None
        # Create the random grid
    )

    estimator = SVC()
    # log-uniform: understand as search over p = exp(x) by varying x
    param_search = BayesSearchCV(
        estimator, search_spaces,
        cv=group_kfold, verbose=2, random_state=42, n_iter=n_iter,
        n_jobs = -1)

    # executes bayesian optimization
    _ = param_search.fit(X=designmtx, y=condition_data, groups=group_assignments)
# Out:
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# [CV] END bootstrap=False, max_depth=47, max_features=sqrt, min_samples_leaf=0.0004281531928076346, n_estimators=348; total time= 1.8min
# [CV] END bootstrap=False, max_depth=47, max_features=sqrt, min_samples_leaf=0.0004281531928076346, n_estimators=348; total time= 2.0min
# [CV] END bootstrap=False, max_depth=47, max_features=sqrt, min_samples_leaf=0.0004281531928076346, n_estimators=348; total time= 1.7min
# [CV] END bootstrap=True, max_depth=108, max_features=log2, min_samples_leaf=0.007988179462781242, n_estimators=974; total time= 1.6min
# [CV] END bootstrap=True, max_depth=108, max_features=log2, min_samples_leaf=0.007988179462781242, n_estimators=974; total time= 1.7min
# [CV] END bootstrap=False, max_depth=130, max_features=log2, min_samples_leaf=0.0007356404539935663, n_estimators=27; total time=   5.2s
# [CV] END bootstrap=False, max_depth=130, max_features=log2, min_samples_leaf=0.0007356404539935663, n_estimators=27; total time=   5.5s
# [CV] END bootstrap=False, max_depth=130, max_features=log2, min_samples_leaf=0.0007356404539935663, n_estimators=27; total time=   5.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=0.0040320839179989465, n_estimators=160; total time=   8.7s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=0.0040320839179989465, n_estimators=160; total time=   8.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=0.0040320839179989465, n_estimators=160; total time=   6.8s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=0.002700390206185342, n_estimators=1202; total time= 3.7min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=0.002700390206185342, n_estimators=1202; total time= 3.5min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=0.002700390206185342, n_estimators=1202; total time= 3.0min
# [CV] END bootstrap=True, max_depth=145, max_features=log2, min_samples_leaf=0.00023814999872958598, n_estimators=695; total time= 1.6min
# [CV] END bootstrap=True, max_depth=145, max_features=log2, min_samples_leaf=0.00023814999872958598, n_estimators=695; total time= 1.6min
# [CV] END bootstrap=True, max_depth=61, max_features=log2, min_samples_leaf=0.005605967693796125, n_estimators=231; total time=  22.6s
# [CV] END bootstrap=True, max_depth=61, max_features=log2, min_samples_leaf=0.005605967693796125, n_estimators=231; total time=  23.4s
# [CV] END bootstrap=True, max_depth=61, max_features=log2, min_samples_leaf=0.005605967693796125, n_estimators=231; total time=  19.9s
# [CV] END bootstrap=True, max_depth=131, max_features=log2, min_samples_leaf=0.004734922490673388, n_estimators=56; total time=   5.9s
# [CV] END bootstrap=True, max_depth=131, max_features=log2, min_samples_leaf=0.004734922490673388, n_estimators=56; total time=   5.9s
# [CV] END bootstrap=True, max_depth=41, max_features=sqrt, min_samples_leaf=0.0006786442521779151, n_estimators=75; total time=  15.1s
# [CV] END bootstrap=True, max_depth=41, max_features=sqrt, min_samples_leaf=0.0006786442521779151, n_estimators=75; total time=  14.7s
# [CV] END bootstrap=True, max_depth=41, max_features=sqrt, min_samples_leaf=0.0006786442521779151, n_estimators=75; total time=  14.1s
# [CV] END bootstrap=False, max_depth=76, max_features=sqrt, min_samples_leaf=0.0003229300915669146, n_estimators=215; total time= 1.1min
# [CV] END bootstrap=False, max_depth=76, max_features=sqrt, min_samples_leaf=0.0003229300915669146, n_estimators=215; total time= 1.2min
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, min_samples_leaf=0.0003094902880740697, n_estimators=181; total time=  16.0s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, min_samples_leaf=0.0003094902880740697, n_estimators=181; total time=  16.3s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, min_samples_leaf=0.0003094902880740697, n_estimators=181; total time=  11.9s
# [CV] END bootstrap=False, max_depth=24, max_features=log2, min_samples_leaf=0.00010029738357550108, n_estimators=115; total time=  22.6s
# [CV] END bootstrap=False, max_depth=24, max_features=log2, min_samples_leaf=0.00010029738357550108, n_estimators=115; total time=  23.0s
# [CV] END bootstrap=False, max_depth=24, max_features=log2, min_samples_leaf=0.00010029738357550108, n_estimators=115; total time=  22.6s
# [CV] END bootstrap=True, max_depth=104, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=18; total time=   3.8s
# [CV] END bootstrap=True, max_depth=104, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=18; total time=   3.8s
# [CV] END bootstrap=True, max_depth=104, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=18; total time=   3.4s
# [CV] END bootstrap=True, max_depth=200, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 7.1min
# [CV] END bootstrap=True, max_depth=200, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 7.7min
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# [CV] END bootstrap=False, max_depth=47, max_features=sqrt, min_samples_leaf=0.0004281531928076346, n_estimators=348; total time= 1.8min
# [CV] END bootstrap=False, max_depth=47, max_features=sqrt, min_samples_leaf=0.0004281531928076346, n_estimators=348; total time= 2.0min
# [CV] END bootstrap=True, max_depth=108, max_features=log2, min_samples_leaf=0.007988179462781242, n_estimators=974; total time= 1.5min
# [CV] END bootstrap=True, max_depth=108, max_features=log2, min_samples_leaf=0.007988179462781242, n_estimators=974; total time= 1.7min
# [CV] END bootstrap=True, max_depth=108, max_features=log2, min_samples_leaf=0.007988179462781242, n_estimators=974; total time= 1.4min
# [CV] END bootstrap=False, max_depth=130, max_features=log2, min_samples_leaf=0.0007356404539935663, n_estimators=27; total time=   5.2s
# [CV] END bootstrap=False, max_depth=130, max_features=log2, min_samples_leaf=0.0007356404539935663, n_estimators=27; total time=   5.8s
# [CV] END bootstrap=False, max_depth=130, max_features=log2, min_samples_leaf=0.0007356404539935663, n_estimators=27; total time=   4.5s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=0.0040320839179989465, n_estimators=160; total time=   8.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=0.0040320839179989465, n_estimators=160; total time=   9.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=0.0040320839179989465, n_estimators=160; total time=   7.4s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=0.002700390206185342, n_estimators=1202; total time= 3.8min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=0.002700390206185342, n_estimators=1202; total time= 3.5min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=0.002700390206185342, n_estimators=1202; total time= 3.0min
# [CV] END bootstrap=True, max_depth=145, max_features=log2, min_samples_leaf=0.00023814999872958598, n_estimators=695; total time= 1.5min
# [CV] END bootstrap=True, max_depth=145, max_features=log2, min_samples_leaf=0.00023814999872958598, n_estimators=695; total time= 1.5min
# [CV] END bootstrap=True, max_depth=145, max_features=log2, min_samples_leaf=0.00023814999872958598, n_estimators=695; total time= 1.4min
# [CV] END bootstrap=True, max_depth=61, max_features=log2, min_samples_leaf=0.005605967693796125, n_estimators=231; total time=  23.5s
# [CV] END bootstrap=True, max_depth=61, max_features=log2, min_samples_leaf=0.005605967693796125, n_estimators=231; total time=  23.9s
# [CV] END bootstrap=True, max_depth=131, max_features=log2, min_samples_leaf=0.004734922490673388, n_estimators=56; total time=   5.7s
# [CV] END bootstrap=True, max_depth=131, max_features=log2, min_samples_leaf=0.004734922490673388, n_estimators=56; total time=   6.0s
# [CV] END bootstrap=True, max_depth=131, max_features=log2, min_samples_leaf=0.004734922490673388, n_estimators=56; total time=   5.5s
# [CV] END bootstrap=True, max_depth=41, max_features=sqrt, min_samples_leaf=0.0006786442521779151, n_estimators=75; total time=  15.1s
# [CV] END bootstrap=True, max_depth=41, max_features=sqrt, min_samples_leaf=0.0006786442521779151, n_estimators=75; total time=  15.6s
# [CV] END bootstrap=False, max_depth=76, max_features=sqrt, min_samples_leaf=0.0003229300915669146, n_estimators=215; total time= 1.1min
# [CV] END bootstrap=False, max_depth=76, max_features=sqrt, min_samples_leaf=0.0003229300915669146, n_estimators=215; total time= 1.1min
# [CV] END bootstrap=False, max_depth=76, max_features=sqrt, min_samples_leaf=0.0003229300915669146, n_estimators=215; total time= 1.0min
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, min_samples_leaf=0.0003094902880740697, n_estimators=181; total time=  16.2s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, min_samples_leaf=0.0003094902880740697, n_estimators=181; total time=  16.3s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, min_samples_leaf=0.0003094902880740697, n_estimators=181; total time=  14.7s
# [CV] END bootstrap=False, max_depth=24, max_features=log2, min_samples_leaf=0.00010029738357550108, n_estimators=115; total time=  23.5s
# [CV] END bootstrap=False, max_depth=24, max_features=log2, min_samples_leaf=0.00010029738357550108, n_estimators=115; total time=  22.8s
# [CV] END bootstrap=False, max_depth=24, max_features=log2, min_samples_leaf=0.00010029738357550108, n_estimators=115; total time=  21.1s
# [CV] END bootstrap=True, max_depth=104, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=18; total time=   3.9s
# [CV] END bootstrap=True, max_depth=104, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=18; total time=   3.7s
# [CV] END bootstrap=True, max_depth=104, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=18; total time=   3.5s
# [CV] END bootstrap=True, max_depth=200, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 7.0min
# [CV] END bootstrap=True, max_depth=200, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 7.3min
# [CV] END bootstrap=True, max_depth=200, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 6.6min
# [CV] END bootstrap=True, max_depth=200, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=10; total time=   2.1s
# [CV] END bootstrap=True, max_depth=200, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=10; total time=   3.3s
# [CV] END bootstrap=True, max_depth=200, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=10; total time=   3.2s
# [CV] END bootstrap=False, max_depth=37, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=1699; total time=10.1min
# [CV] END bootstrap=False, max_depth=37, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=1699; total time=10.8min
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# [CV] END bootstrap=False, max_depth=47, max_features=sqrt, min_samples_leaf=0.0004281531928076346, n_estimators=348; total time= 1.8min
# [CV] END bootstrap=False, max_depth=47, max_features=sqrt, min_samples_leaf=0.0004281531928076346, n_estimators=348; total time= 1.9min
# [CV] END bootstrap=False, max_depth=47, max_features=sqrt, min_samples_leaf=0.0004281531928076346, n_estimators=348; total time= 1.7min
# [CV] END bootstrap=True, max_depth=108, max_features=log2, min_samples_leaf=0.007988179462781242, n_estimators=974; total time= 1.6min
# [CV] END bootstrap=True, max_depth=108, max_features=log2, min_samples_leaf=0.007988179462781242, n_estimators=974; total time= 1.8min
# [CV] END bootstrap=True, max_depth=108, max_features=log2, min_samples_leaf=0.007988179462781242, n_estimators=974; total time= 1.4min
# [CV] END bootstrap=False, max_depth=130, max_features=log2, min_samples_leaf=0.0007356404539935663, n_estimators=27; total time=   5.3s
# [CV] END bootstrap=False, max_depth=130, max_features=log2, min_samples_leaf=0.0007356404539935663, n_estimators=27; total time=   5.4s
# [CV] END bootstrap=False, max_depth=130, max_features=log2, min_samples_leaf=0.0007356404539935663, n_estimators=27; total time=   5.1s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=0.0040320839179989465, n_estimators=160; total time=   9.3s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=0.0040320839179989465, n_estimators=160; total time=   8.7s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=0.002700390206185342, n_estimators=1202; total time= 3.7min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=0.002700390206185342, n_estimators=1202; total time= 3.5min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=0.002700390206185342, n_estimators=1202; total time= 2.8min
# [CV] END bootstrap=True, max_depth=145, max_features=log2, min_samples_leaf=0.00023814999872958598, n_estimators=695; total time= 1.5min
# [CV] END bootstrap=True, max_depth=145, max_features=log2, min_samples_leaf=0.00023814999872958598, n_estimators=695; total time= 1.6min
# [CV] END bootstrap=True, max_depth=145, max_features=log2, min_samples_leaf=0.00023814999872958598, n_estimators=695; total time= 1.4min
# [CV] END bootstrap=True, max_depth=61, max_features=log2, min_samples_leaf=0.005605967693796125, n_estimators=231; total time=  22.7s
# [CV] END bootstrap=True, max_depth=61, max_features=log2, min_samples_leaf=0.005605967693796125, n_estimators=231; total time=  24.1s
# [CV] END bootstrap=True, max_depth=61, max_features=log2, min_samples_leaf=0.005605967693796125, n_estimators=231; total time=  21.7s
# [CV] END bootstrap=True, max_depth=131, max_features=log2, min_samples_leaf=0.004734922490673388, n_estimators=56; total time=   5.8s
# [CV] END bootstrap=True, max_depth=131, max_features=log2, min_samples_leaf=0.004734922490673388, n_estimators=56; total time=   5.7s
# [CV] END bootstrap=True, max_depth=131, max_features=log2, min_samples_leaf=0.004734922490673388, n_estimators=56; total time=   4.6s
# [CV] END bootstrap=True, max_depth=41, max_features=sqrt, min_samples_leaf=0.0006786442521779151, n_estimators=75; total time=  14.8s
# [CV] END bootstrap=True, max_depth=41, max_features=sqrt, min_samples_leaf=0.0006786442521779151, n_estimators=75; total time=  15.1s
# [CV] END bootstrap=True, max_depth=41, max_features=sqrt, min_samples_leaf=0.0006786442521779151, n_estimators=75; total time=  11.0s
# [CV] END bootstrap=False, max_depth=76, max_features=sqrt, min_samples_leaf=0.0003229300915669146, n_estimators=215; total time= 1.1min
# [CV] END bootstrap=False, max_depth=76, max_features=sqrt, min_samples_leaf=0.0003229300915669146, n_estimators=215; total time= 1.1min
# [CV] END bootstrap=False, max_depth=76, max_features=sqrt, min_samples_leaf=0.0003229300915669146, n_estimators=215; total time= 1.0min
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, min_samples_leaf=0.0003094902880740697, n_estimators=181; total time=  16.3s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, min_samples_leaf=0.0003094902880740697, n_estimators=181; total time=  16.7s
# [CV] END bootstrap=False, max_depth=24, max_features=log2, min_samples_leaf=0.00010029738357550108, n_estimators=115; total time=  23.4s
# [CV] END bootstrap=False, max_depth=24, max_features=log2, min_samples_leaf=0.00010029738357550108, n_estimators=115; total time=  24.8s
# [CV] END bootstrap=True, max_depth=104, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=18; total time=   3.8s
# [CV] END bootstrap=True, max_depth=104, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=18; total time=   3.8s
# [CV] END bootstrap=True, max_depth=104, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=18; total time=   3.0s
# [CV] END bootstrap=True, max_depth=200, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 6.9min
# [CV] END bootstrap=True, max_depth=200, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 7.3min
# [CV] END bootstrap=True, max_depth=200, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 6.8min
# [CV] END bootstrap=True, max_depth=200, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=10; total time=   2.1s
# [CV] END bootstrap=True, max_depth=200, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=10; total time=   3.5s
# [CV] END bootstrap=True, max_depth=200, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=10; total time=   2.8s
# [CV] END bootstrap=False, max_depth=37, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=1699; total time=10.0min
# [CV] END bootstrap=False, max_depth=37, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=1699; total time=10.4min
# [CV] END bootstrap=False, max_depth=37, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=1699; total time= 8.7min
# [CV] END bootstrap=False, max_depth=65, max_features=sqrt, min_samples_leaf=0.009982016069901197, n_estimators=139; total time=  33.6s
# [CV] END bootstrap=False, max_depth=65, max_features=sqrt, min_samples_leaf=0.009982016069901197, n_estimators=139; total time=  37.0s
# [CV] END bootstrap=False, max_depth=65, max_features=sqrt, min_samples_leaf=0.009982016069901197, n_estimators=139; total time=  32.1s
# [CV] END bootstrap=True, max_depth=96, max_features=sqrt, min_samples_leaf=0.009997480362552637, n_estimators=73; total time=  10.3s
# [CV] END bootstrap=True, max_depth=96, max_features=sqrt, min_samples_leaf=0.009997480362552637, n_estimators=73; total time=  10.9s
# [CV] END bootstrap=True, max_depth=96, max_features=sqrt, min_samples_leaf=0.009997480362552637, n_estimators=73; total time=   8.5s
# [CV] END bootstrap=False, max_depth=1, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=343; total time=  12.9s
# [CV] END bootstrap=False, max_depth=1, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=343; total time=  13.3s
# [CV] END bootstrap=False, max_depth=1, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=343; total time=  11.3s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=0.00010193987535523606, n_estimators=46; total time=   2.2s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=0.00010193987535523606, n_estimators=46; total time=   2.4s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=0.00010193987535523606, n_estimators=46; total time=   2.0s
# [CV] END bootstrap=False, max_depth=200, max_features=sqrt, min_samples_leaf=0.00034237678586013833, n_estimators=436; total time= 2.3min
# [CV] END bootstrap=False, max_depth=200, max_features=sqrt, min_samples_leaf=0.00034237678586013833, n_estimators=436; total time= 2.3min
# [CV] END bootstrap=False, max_depth=200, max_features=sqrt, min_samples_leaf=0.00034237678586013833, n_estimators=436; total time= 2.1min
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=0.008968755458942886, n_estimators=1865; total time=  42.7s
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=0.008968755458942886, n_estimators=1865; total time=  46.0s
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# [CV] END bootstrap=False, max_depth=47, max_features=sqrt, min_samples_leaf=0.0004281531928076346, n_estimators=348; total time= 1.8min
# [CV] END bootstrap=False, max_depth=47, max_features=sqrt, min_samples_leaf=0.0004281531928076346, n_estimators=348; total time= 1.9min
# [CV] END bootstrap=False, max_depth=47, max_features=sqrt, min_samples_leaf=0.0004281531928076346, n_estimators=348; total time= 1.8min
# [CV] END bootstrap=True, max_depth=108, max_features=log2, min_samples_leaf=0.007988179462781242, n_estimators=974; total time= 1.6min
# [CV] END bootstrap=True, max_depth=108, max_features=log2, min_samples_leaf=0.007988179462781242, n_estimators=974; total time= 1.6min
# [CV] END bootstrap=True, max_depth=108, max_features=log2, min_samples_leaf=0.007988179462781242, n_estimators=974; total time= 1.4min
# [CV] END bootstrap=False, max_depth=130, max_features=log2, min_samples_leaf=0.0007356404539935663, n_estimators=27; total time=   5.3s
# [CV] END bootstrap=False, max_depth=130, max_features=log2, min_samples_leaf=0.0007356404539935663, n_estimators=27; total time=   5.8s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=0.0040320839179989465, n_estimators=160; total time=   8.6s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=0.0040320839179989465, n_estimators=160; total time=   8.9s
# [CV] END bootstrap=True, max_depth=2, max_features=sqrt, min_samples_leaf=0.0040320839179989465, n_estimators=160; total time=   6.9s
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=0.002700390206185342, n_estimators=1202; total time= 3.8min
# [CV] END bootstrap=True, max_depth=10, max_features=sqrt, min_samples_leaf=0.002700390206185342, n_estimators=1202; total time= 3.6min
# [CV] END bootstrap=True, max_depth=145, max_features=log2, min_samples_leaf=0.00023814999872958598, n_estimators=695; total time= 1.5min
# [CV] END bootstrap=True, max_depth=145, max_features=log2, min_samples_leaf=0.00023814999872958598, n_estimators=695; total time= 1.5min
# [CV] END bootstrap=True, max_depth=145, max_features=log2, min_samples_leaf=0.00023814999872958598, n_estimators=695; total time= 1.4min
# [CV] END bootstrap=True, max_depth=61, max_features=log2, min_samples_leaf=0.005605967693796125, n_estimators=231; total time=  23.2s
# [CV] END bootstrap=True, max_depth=61, max_features=log2, min_samples_leaf=0.005605967693796125, n_estimators=231; total time=  22.9s
# [CV] END bootstrap=True, max_depth=61, max_features=log2, min_samples_leaf=0.005605967693796125, n_estimators=231; total time=  18.9s
# [CV] END bootstrap=True, max_depth=131, max_features=log2, min_samples_leaf=0.004734922490673388, n_estimators=56; total time=   5.8s
# [CV] END bootstrap=True, max_depth=131, max_features=log2, min_samples_leaf=0.004734922490673388, n_estimators=56; total time=   5.9s
# [CV] END bootstrap=True, max_depth=131, max_features=log2, min_samples_leaf=0.004734922490673388, n_estimators=56; total time=   5.1s
# [CV] END bootstrap=True, max_depth=41, max_features=sqrt, min_samples_leaf=0.0006786442521779151, n_estimators=75; total time=  15.0s
# [CV] END bootstrap=True, max_depth=41, max_features=sqrt, min_samples_leaf=0.0006786442521779151, n_estimators=75; total time=  15.5s
# [CV] END bootstrap=True, max_depth=41, max_features=sqrt, min_samples_leaf=0.0006786442521779151, n_estimators=75; total time=  14.2s
# [CV] END bootstrap=False, max_depth=76, max_features=sqrt, min_samples_leaf=0.0003229300915669146, n_estimators=215; total time= 1.1min
# [CV] END bootstrap=False, max_depth=76, max_features=sqrt, min_samples_leaf=0.0003229300915669146, n_estimators=215; total time= 1.2min
# [CV] END bootstrap=False, max_depth=76, max_features=sqrt, min_samples_leaf=0.0003229300915669146, n_estimators=215; total time=  58.9s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, min_samples_leaf=0.0003094902880740697, n_estimators=181; total time=  16.3s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, min_samples_leaf=0.0003094902880740697, n_estimators=181; total time=  16.7s
# [CV] END bootstrap=True, max_depth=4, max_features=sqrt, min_samples_leaf=0.0003094902880740697, n_estimators=181; total time=  14.9s
# [CV] END bootstrap=False, max_depth=24, max_features=log2, min_samples_leaf=0.00010029738357550108, n_estimators=115; total time=  23.7s
# [CV] END bootstrap=False, max_depth=24, max_features=log2, min_samples_leaf=0.00010029738357550108, n_estimators=115; total time=  24.2s
# [CV] END bootstrap=False, max_depth=24, max_features=log2, min_samples_leaf=0.00010029738357550108, n_estimators=115; total time=  19.9s
# [CV] END bootstrap=True, max_depth=104, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=18; total time=   4.0s
# [CV] END bootstrap=True, max_depth=104, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=18; total time=   4.0s
# [CV] END bootstrap=True, max_depth=200, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 7.0min
# [CV] END bootstrap=True, max_depth=200, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 7.7min
# [CV] END bootstrap=True, max_depth=200, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 6.4min
# [CV] END bootstrap=True, max_depth=200, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=10; total time=   2.3s
# [CV] END bootstrap=True, max_depth=200, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=10; total time=   2.7s
# [CV] END bootstrap=True, max_depth=200, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=10; total time=   3.1s
# [CV] END bootstrap=False, max_depth=37, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=1699; total time= 9.9min
# [CV] END bootstrap=False, max_depth=37, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=1699; total time=10.0min
# [CV] END bootstrap=False, max_depth=37, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=1699; total time= 9.1min
# [CV] END bootstrap=False, max_depth=65, max_features=sqrt, min_samples_leaf=0.009982016069901197, n_estimators=139; total time=  33.7s
# [CV] END bootstrap=False, max_depth=65, max_features=sqrt, min_samples_leaf=0.009982016069901197, n_estimators=139; total time=  33.1s
# [CV] END bootstrap=False, max_depth=65, max_features=sqrt, min_samples_leaf=0.009982016069901197, n_estimators=139; total time=  28.2s
# [CV] END bootstrap=True, max_depth=96, max_features=sqrt, min_samples_leaf=0.009997480362552637, n_estimators=73; total time=  10.7s
# [CV] END bootstrap=True, max_depth=96, max_features=sqrt, min_samples_leaf=0.009997480362552637, n_estimators=73; total time=  10.7s
# [CV] END bootstrap=True, max_depth=96, max_features=sqrt, min_samples_leaf=0.009997480362552637, n_estimators=73; total time=   9.7s
# [CV] END bootstrap=False, max_depth=1, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=343; total time=  12.9s
# [CV] END bootstrap=False, max_depth=1, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=343; total time=  13.5s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=0.00010193987535523606, n_estimators=46; total time=   2.7s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=0.00010193987535523606, n_estimators=46; total time=   2.2s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=0.00010193987535523606, n_estimators=46; total time=   1.6s
# [CV] END bootstrap=False, max_depth=200, max_features=sqrt, min_samples_leaf=0.00034237678586013833, n_estimators=436; total time= 2.3min
# [CV] END bootstrap=False, max_depth=200, max_features=sqrt, min_samples_leaf=0.00034237678586013833, n_estimators=436; total time= 2.3min
# [CV] END bootstrap=False, max_depth=200, max_features=sqrt, min_samples_leaf=0.00034237678586013833, n_estimators=436; total time= 2.1min
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=0.008968755458942886, n_estimators=1865; total time=  43.1s
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=0.008968755458942886, n_estimators=1865; total time=  47.4s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.00032828990339886245, n_estimators=15; total time=   3.3s
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# [CV] END bootstrap=True, max_depth=200, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=10; total time=   2.2s
# [CV] END bootstrap=True, max_depth=200, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=10; total time=   2.7s
# [CV] END bootstrap=False, max_depth=37, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=1699; total time=10.0min
# [CV] END bootstrap=False, max_depth=37, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=1699; total time= 9.9min
# [CV] END bootstrap=False, max_depth=37, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=1699; total time= 8.7min
# [CV] END bootstrap=False, max_depth=65, max_features=sqrt, min_samples_leaf=0.009982016069901197, n_estimators=139; total time=  32.4s
# [CV] END bootstrap=False, max_depth=65, max_features=sqrt, min_samples_leaf=0.009982016069901197, n_estimators=139; total time=  34.7s
# [CV] END bootstrap=False, max_depth=65, max_features=sqrt, min_samples_leaf=0.009982016069901197, n_estimators=139; total time=  31.1s
# [CV] END bootstrap=True, max_depth=96, max_features=sqrt, min_samples_leaf=0.009997480362552637, n_estimators=73; total time=  10.9s
# [CV] END bootstrap=True, max_depth=96, max_features=sqrt, min_samples_leaf=0.009997480362552637, n_estimators=73; total time=  11.4s
# [CV] END bootstrap=False, max_depth=1, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=343; total time=  12.9s
# [CV] END bootstrap=False, max_depth=1, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=343; total time=  13.3s
# [CV] END bootstrap=False, max_depth=1, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=343; total time=  12.7s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=0.00010193987535523606, n_estimators=46; total time=   2.2s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=0.00010193987535523606, n_estimators=46; total time=   2.7s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=0.00010193987535523606, n_estimators=46; total time=   1.9s
# [CV] END bootstrap=False, max_depth=200, max_features=sqrt, min_samples_leaf=0.00034237678586013833, n_estimators=436; total time= 2.3min
# [CV] END bootstrap=False, max_depth=200, max_features=sqrt, min_samples_leaf=0.00034237678586013833, n_estimators=436; total time= 2.4min
# [CV] END bootstrap=False, max_depth=200, max_features=sqrt, min_samples_leaf=0.00034237678586013833, n_estimators=436; total time= 2.1min
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=0.008968755458942886, n_estimators=1865; total time=  43.0s
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=0.008968755458942886, n_estimators=1865; total time=  47.0s
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=0.008968755458942886, n_estimators=1865; total time=  39.1s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.00032828990339886245, n_estimators=15; total time=   3.2s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.00032828990339886245, n_estimators=15; total time=   3.2s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.00032828990339886245, n_estimators=15; total time=   3.1s
# [CV] END bootstrap=False, max_depth=11, max_features=sqrt, min_samples_leaf=0.004343175370855223, n_estimators=10; total time=   2.6s
# [CV] END bootstrap=False, max_depth=11, max_features=sqrt, min_samples_leaf=0.004343175370855223, n_estimators=10; total time=   2.6s
# [CV] END bootstrap=False, max_depth=11, max_features=sqrt, min_samples_leaf=0.004343175370855223, n_estimators=10; total time=   2.2s
# [CV] END bootstrap=True, max_depth=23, max_features=sqrt, min_samples_leaf=0.00011996393851034338, n_estimators=567; total time= 2.0min
# [CV] END bootstrap=True, max_depth=23, max_features=sqrt, min_samples_leaf=0.00011996393851034338, n_estimators=567; total time= 2.0min
# [CV] END bootstrap=True, max_depth=23, max_features=sqrt, min_samples_leaf=0.00011996393851034338, n_estimators=567; total time= 1.9min
# [CV] END bootstrap=False, max_depth=199, max_features=sqrt, min_samples_leaf=0.00010952616986110853, n_estimators=28; total time=   9.1s
# [CV] END bootstrap=False, max_depth=199, max_features=sqrt, min_samples_leaf=0.00010952616986110853, n_estimators=28; total time=   9.5s
# [CV] END bootstrap=False, max_depth=199, max_features=sqrt, min_samples_leaf=0.00010952616986110853, n_estimators=28; total time=   6.9s
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=0.00013316128902388574, n_estimators=14; total time=   0.4s
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=0.00013316128902388574, n_estimators=14; total time=   0.4s
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=0.00013316128902388574, n_estimators=14; total time=   0.4s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.00034176919671622405, n_estimators=11; total time=   2.3s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.00034176919671622405, n_estimators=11; total time=   2.4s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.000179710324904446, n_estimators=12; total time=   2.7s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.000179710324904446, n_estimators=12; total time=   2.5s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.000179710324904446, n_estimators=12; total time=   2.5s
# [CV] END bootstrap=False, max_depth=200, max_features=log2, min_samples_leaf=0.002696340107674908, n_estimators=191; total time=  34.2s
# [CV] END bootstrap=False, max_depth=200, max_features=log2, min_samples_leaf=0.002696340107674908, n_estimators=191; total time=  35.3s
# [CV] END bootstrap=False, max_depth=200, max_features=log2, min_samples_leaf=0.002696340107674908, n_estimators=191; total time=  31.3s
# [CV] END bootstrap=True, max_depth=34, max_features=sqrt, min_samples_leaf=0.005307835661434245, n_estimators=1166; total time= 3.3min
# [CV] END bootstrap=True, max_depth=34, max_features=sqrt, min_samples_leaf=0.005307835661434245, n_estimators=1166; total time= 3.1min
# [CV] END bootstrap=True, max_depth=34, max_features=sqrt, min_samples_leaf=0.005307835661434245, n_estimators=1166; total time= 2.9min
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=0.009916637155417315, n_estimators=1892; total time=  49.6s
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=0.009916637155417315, n_estimators=1892; total time=  50.6s
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=0.009916637155417315, n_estimators=1892; total time=  43.7s
# [CV] END bootstrap=True, max_depth=193, max_features=sqrt, min_samples_leaf=0.0011914916745879788, n_estimators=1998; total time= 6.6min
# [CV] END bootstrap=True, max_depth=193, max_features=sqrt, min_samples_leaf=0.0011914916745879788, n_estimators=1998; total time= 6.8min
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# [CV] END bootstrap=False, max_depth=65, max_features=sqrt, min_samples_leaf=0.009982016069901197, n_estimators=139; total time=  33.8s
# [CV] END bootstrap=False, max_depth=65, max_features=sqrt, min_samples_leaf=0.009982016069901197, n_estimators=139; total time=  35.7s
# [CV] END bootstrap=True, max_depth=96, max_features=sqrt, min_samples_leaf=0.009997480362552637, n_estimators=73; total time=  10.6s
# [CV] END bootstrap=True, max_depth=96, max_features=sqrt, min_samples_leaf=0.009997480362552637, n_estimators=73; total time=  11.2s
# [CV] END bootstrap=True, max_depth=96, max_features=sqrt, min_samples_leaf=0.009997480362552637, n_estimators=73; total time=  10.2s
# [CV] END bootstrap=False, max_depth=1, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=343; total time=  12.8s
# [CV] END bootstrap=False, max_depth=1, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=343; total time=  13.2s
# [CV] END bootstrap=False, max_depth=1, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=343; total time=  11.3s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=0.00010193987535523606, n_estimators=46; total time=   2.7s
# [CV] END bootstrap=True, max_depth=3, max_features=log2, min_samples_leaf=0.00010193987535523606, n_estimators=46; total time=   2.5s
# [CV] END bootstrap=False, max_depth=200, max_features=sqrt, min_samples_leaf=0.00034237678586013833, n_estimators=436; total time= 2.3min
# [CV] END bootstrap=False, max_depth=200, max_features=sqrt, min_samples_leaf=0.00034237678586013833, n_estimators=436; total time= 2.5min
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=0.008968755458942886, n_estimators=1865; total time=  42.5s
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=0.008968755458942886, n_estimators=1865; total time=  46.4s
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=0.008968755458942886, n_estimators=1865; total time=  40.2s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.00032828990339886245, n_estimators=15; total time=   3.4s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.00032828990339886245, n_estimators=15; total time=   3.3s
# [CV] END bootstrap=False, max_depth=11, max_features=sqrt, min_samples_leaf=0.004343175370855223, n_estimators=10; total time=   2.5s
# [CV] END bootstrap=False, max_depth=11, max_features=sqrt, min_samples_leaf=0.004343175370855223, n_estimators=10; total time=   2.6s
# [CV] END bootstrap=False, max_depth=11, max_features=sqrt, min_samples_leaf=0.004343175370855223, n_estimators=10; total time=   2.5s
# [CV] END bootstrap=True, max_depth=23, max_features=sqrt, min_samples_leaf=0.00011996393851034338, n_estimators=567; total time= 2.0min
# [CV] END bootstrap=True, max_depth=23, max_features=sqrt, min_samples_leaf=0.00011996393851034338, n_estimators=567; total time= 2.0min
# [CV] END bootstrap=True, max_depth=23, max_features=sqrt, min_samples_leaf=0.00011996393851034338, n_estimators=567; total time= 1.7min
# [CV] END bootstrap=False, max_depth=199, max_features=sqrt, min_samples_leaf=0.00010952616986110853, n_estimators=28; total time=   9.0s
# [CV] END bootstrap=False, max_depth=199, max_features=sqrt, min_samples_leaf=0.00010952616986110853, n_estimators=28; total time=   9.0s
# [CV] END bootstrap=False, max_depth=199, max_features=sqrt, min_samples_leaf=0.00010952616986110853, n_estimators=28; total time=   8.6s
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=0.00013316128902388574, n_estimators=14; total time=   0.4s
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=0.00013316128902388574, n_estimators=14; total time=   0.4s
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=0.00013316128902388574, n_estimators=14; total time=   0.4s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.00034176919671622405, n_estimators=11; total time=   2.3s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.00034176919671622405, n_estimators=11; total time=   2.3s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.00034176919671622405, n_estimators=11; total time=   2.2s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.000179710324904446, n_estimators=12; total time=   2.6s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.000179710324904446, n_estimators=12; total time=   2.7s
# [CV] END bootstrap=False, max_depth=200, max_features=log2, min_samples_leaf=0.002696340107674908, n_estimators=191; total time=  33.1s
# [CV] END bootstrap=False, max_depth=200, max_features=log2, min_samples_leaf=0.002696340107674908, n_estimators=191; total time=  34.4s
# [CV] END bootstrap=False, max_depth=200, max_features=log2, min_samples_leaf=0.002696340107674908, n_estimators=191; total time=  30.3s
# [CV] END bootstrap=True, max_depth=34, max_features=sqrt, min_samples_leaf=0.005307835661434245, n_estimators=1166; total time= 3.3min
# [CV] END bootstrap=True, max_depth=34, max_features=sqrt, min_samples_leaf=0.005307835661434245, n_estimators=1166; total time= 3.4min
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=0.009916637155417315, n_estimators=1892; total time=  50.2s
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=0.009916637155417315, n_estimators=1892; total time=  52.5s
# [CV] END bootstrap=True, max_depth=193, max_features=sqrt, min_samples_leaf=0.0011914916745879788, n_estimators=1998; total time= 6.5min
# [CV] END bootstrap=True, max_depth=193, max_features=sqrt, min_samples_leaf=0.0011914916745879788, n_estimators=1998; total time= 6.9min
# [CV] END bootstrap=True, max_depth=193, max_features=sqrt, min_samples_leaf=0.0011914916745879788, n_estimators=1998; total time= 5.9min
# [CV] END bootstrap=False, max_depth=200, max_features=sqrt, min_samples_leaf=0.0023221124149211104, n_estimators=1954; total time=10.0min
# [CV] END bootstrap=False, max_depth=200, max_features=sqrt, min_samples_leaf=0.0023221124149211104, n_estimators=1954; total time=10.3min
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# [CV] END bootstrap=False, max_depth=200, max_features=sqrt, min_samples_leaf=0.0023221124149211104, n_estimators=1954; total time= 9.9min
# [CV] END bootstrap=False, max_depth=200, max_features=sqrt, min_samples_leaf=0.0023221124149211104, n_estimators=1954; total time= 9.7min
# [CV] END bootstrap=False, max_depth=200, max_features=sqrt, min_samples_leaf=0.0023221124149211104, n_estimators=1954; total time= 8.0min
# [CV] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=0.009828231894078289, n_estimators=1565; total time= 3.5min
# [CV] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=0.009828231894078289, n_estimators=1565; total time= 3.7min
# [CV] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=0.009828231894078289, n_estimators=1565; total time= 3.2min
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=0.005842563302866546, n_estimators=1640; total time= 6.7min
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=0.005842563302866546, n_estimators=1640; total time= 7.1min
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=0.008968755458942886, n_estimators=1865; total time=  37.5s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.00032828990339886245, n_estimators=15; total time=   3.3s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.00032828990339886245, n_estimators=15; total time=   3.3s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.00032828990339886245, n_estimators=15; total time=   2.4s
# [CV] END bootstrap=False, max_depth=11, max_features=sqrt, min_samples_leaf=0.004343175370855223, n_estimators=10; total time=   2.5s
# [CV] END bootstrap=False, max_depth=11, max_features=sqrt, min_samples_leaf=0.004343175370855223, n_estimators=10; total time=   2.5s
# [CV] END bootstrap=False, max_depth=11, max_features=sqrt, min_samples_leaf=0.004343175370855223, n_estimators=10; total time=   2.4s
# [CV] END bootstrap=True, max_depth=23, max_features=sqrt, min_samples_leaf=0.00011996393851034338, n_estimators=567; total time= 2.1min
# [CV] END bootstrap=True, max_depth=23, max_features=sqrt, min_samples_leaf=0.00011996393851034338, n_estimators=567; total time= 2.1min
# [CV] END bootstrap=False, max_depth=199, max_features=sqrt, min_samples_leaf=0.00010952616986110853, n_estimators=28; total time=   9.3s
# [CV] END bootstrap=False, max_depth=199, max_features=sqrt, min_samples_leaf=0.00010952616986110853, n_estimators=28; total time=   9.5s
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=0.00013316128902388574, n_estimators=14; total time=   0.4s
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=0.00013316128902388574, n_estimators=14; total time=   0.4s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.00034176919671622405, n_estimators=11; total time=   2.2s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.00034176919671622405, n_estimators=11; total time=   2.3s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.00034176919671622405, n_estimators=11; total time=   1.9s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.000179710324904446, n_estimators=12; total time=   2.5s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.000179710324904446, n_estimators=12; total time=   2.5s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.000179710324904446, n_estimators=12; total time=   2.1s
# [CV] END bootstrap=False, max_depth=200, max_features=log2, min_samples_leaf=0.002696340107674908, n_estimators=191; total time=  33.9s
# [CV] END bootstrap=False, max_depth=200, max_features=log2, min_samples_leaf=0.002696340107674908, n_estimators=191; total time=  34.0s
# [CV] END bootstrap=False, max_depth=200, max_features=log2, min_samples_leaf=0.002696340107674908, n_estimators=191; total time=  29.1s
# [CV] END bootstrap=True, max_depth=34, max_features=sqrt, min_samples_leaf=0.005307835661434245, n_estimators=1166; total time= 3.3min
# [CV] END bootstrap=True, max_depth=34, max_features=sqrt, min_samples_leaf=0.005307835661434245, n_estimators=1166; total time= 3.4min
# [CV] END bootstrap=True, max_depth=34, max_features=sqrt, min_samples_leaf=0.005307835661434245, n_estimators=1166; total time= 2.8min
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=0.009916637155417315, n_estimators=1892; total time=  49.9s
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=0.009916637155417315, n_estimators=1892; total time=  51.0s
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=0.009916637155417315, n_estimators=1892; total time=  47.4s
# [CV] END bootstrap=True, max_depth=193, max_features=sqrt, min_samples_leaf=0.0011914916745879788, n_estimators=1998; total time= 6.5min
# ...
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=0.005842563302866546, n_estimators=1640; total time= 7.0min
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=0.005842563302866546, n_estimators=1640; total time= 6.3min
# [CV] END bootstrap=True, max_depth=42, max_features=sqrt, min_samples_leaf=0.00010136608061102067, n_estimators=1450; total time= 5.4min
# [CV] END bootstrap=True, max_depth=42, max_features=sqrt, min_samples_leaf=0.00010136608061102067, n_estimators=1450; total time= 5.5min
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=0.009208297537457222, n_estimators=15; total time=   0.3s
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=0.009208297537457222, n_estimators=15; total time=   0.3s
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=0.009208297537457222, n_estimators=15; total time=   0.3s
# [CV] END bootstrap=True, max_depth=195, max_features=sqrt, min_samples_leaf=0.00886382395053588, n_estimators=14; total time=   2.3s
# [CV] END bootstrap=True, max_depth=195, max_features=sqrt, min_samples_leaf=0.00886382395053588, n_estimators=14; total time=   2.4s
# [CV] END bootstrap=True, max_depth=195, max_features=sqrt, min_samples_leaf=0.00886382395053588, n_estimators=14; total time=   2.1s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, min_samples_leaf=0.005524305838087087, n_estimators=11; total time=   2.0s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, min_samples_leaf=0.005524305838087087, n_estimators=11; total time=   2.3s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, min_samples_leaf=0.005524305838087087, n_estimators=11; total time=   1.6s
# [CV] END bootstrap=False, max_depth=62, max_features=sqrt, min_samples_leaf=0.005398827110843554, n_estimators=10; total time=   3.6s
# [CV] END bootstrap=False, max_depth=62, max_features=sqrt, min_samples_leaf=0.005398827110843554, n_estimators=10; total time=   3.2s
# [CV] END bootstrap=False, max_depth=62, max_features=sqrt, min_samples_leaf=0.005398827110843554, n_estimators=10; total time=   3.0s
# [CV] END bootstrap=False, max_depth=14, max_features=log2, min_samples_leaf=0.00016276726149398857, n_estimators=10; total time=   2.4s
# [CV] END bootstrap=False, max_depth=14, max_features=log2, min_samples_leaf=0.00016276726149398857, n_estimators=10; total time=   2.6s
# [CV] END bootstrap=False, max_depth=14, max_features=log2, min_samples_leaf=0.00016276726149398857, n_estimators=10; total time=   1.6s
# [CV] END bootstrap=False, max_depth=48, max_features=sqrt, min_samples_leaf=0.0007198269015019031, n_estimators=31; total time=  12.2s
# [CV] END bootstrap=False, max_depth=48, max_features=sqrt, min_samples_leaf=0.0007198269015019031, n_estimators=31; total time=  10.8s
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=0.00010402038686341951, n_estimators=1932; total time=  53.0s
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# [CV] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=0.009828231894078289, n_estimators=1565; total time= 3.5min
# [CV] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=0.009828231894078289, n_estimators=1565; total time= 3.6min
# [CV] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=0.009828231894078289, n_estimators=1565; total time= 3.3min
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=0.005842563302866546, n_estimators=1640; total time= 6.7min
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=0.005842563302866546, n_estimators=1640; total time= 6.8min
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=0.005842563302866546, n_estimators=1640; total time= 5.8min
# [CV] END bootstrap=True, max_depth=42, max_features=sqrt, min_samples_leaf=0.00010136608061102067, n_estimators=1450; total time= 5.4min
# [CV] END bootstrap=True, max_depth=42, max_features=sqrt, min_samples_leaf=0.00010136608061102067, n_estimators=1450; total time= 5.5min
# [CV] END bootstrap=True, max_depth=42, max_features=sqrt, min_samples_leaf=0.00010136608061102067, n_estimators=1450; total time= 4.6min
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=0.009208297537457222, n_estimators=15; total time=   0.3s
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=0.009208297537457222, n_estimators=15; total time=   0.3s
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=0.009208297537457222, n_estimators=15; total time=   0.3s
# [CV] END bootstrap=True, max_depth=195, max_features=sqrt, min_samples_leaf=0.00886382395053588, n_estimators=14; total time=   2.1s
# [CV] END bootstrap=True, max_depth=195, max_features=sqrt, min_samples_leaf=0.00886382395053588, n_estimators=14; total time=   2.3s
# [CV] END bootstrap=True, max_depth=195, max_features=sqrt, min_samples_leaf=0.00886382395053588, n_estimators=14; total time=   2.2s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, min_samples_leaf=0.005524305838087087, n_estimators=11; total time=   1.8s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, min_samples_leaf=0.005524305838087087, n_estimators=11; total time=   2.3s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, min_samples_leaf=0.005524305838087087, n_estimators=11; total time=   1.6s
# [CV] END bootstrap=False, max_depth=62, max_features=sqrt, min_samples_leaf=0.005398827110843554, n_estimators=10; total time=   3.7s
# [CV] END bootstrap=False, max_depth=62, max_features=sqrt, min_samples_leaf=0.005398827110843554, n_estimators=10; total time=   3.7s
# [CV] END bootstrap=False, max_depth=14, max_features=log2, min_samples_leaf=0.00016276726149398857, n_estimators=10; total time=   2.7s
# [CV] END bootstrap=False, max_depth=14, max_features=log2, min_samples_leaf=0.00016276726149398857, n_estimators=10; total time=   2.6s
# [CV] END bootstrap=False, max_depth=14, max_features=log2, min_samples_leaf=0.00016276726149398857, n_estimators=10; total time=   1.8s
# [CV] END bootstrap=False, max_depth=48, max_features=sqrt, min_samples_leaf=0.0007198269015019031, n_estimators=31; total time=  12.0s
# [CV] END bootstrap=False, max_depth=48, max_features=sqrt, min_samples_leaf=0.0007198269015019031, n_estimators=31; total time=  10.1s
# [CV] END bootstrap=False, max_depth=48, max_features=sqrt, min_samples_leaf=0.0007198269015019031, n_estimators=31; total time=   8.8s
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=0.00010402038686341951, n_estimators=1932; total time=  53.7s
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=0.00010402038686341951, n_estimators=1932; total time=  46.5s
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=0.00010402038686341951, n_estimators=1932; total time=  44.4s
# [CV] END bootstrap=True, max_depth=37, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 7.7min
# [CV] END bootstrap=True, max_depth=37, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 8.6min
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.00032828990339886245, n_estimators=15; total time=   3.1s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.00032828990339886245, n_estimators=15; total time=   2.9s
# [CV] END bootstrap=False, max_depth=11, max_features=sqrt, min_samples_leaf=0.004343175370855223, n_estimators=10; total time=   2.7s
# [CV] END bootstrap=False, max_depth=11, max_features=sqrt, min_samples_leaf=0.004343175370855223, n_estimators=10; total time=   2.8s
# [CV] END bootstrap=True, max_depth=23, max_features=sqrt, min_samples_leaf=0.00011996393851034338, n_estimators=567; total time= 2.0min
# [CV] END bootstrap=True, max_depth=23, max_features=sqrt, min_samples_leaf=0.00011996393851034338, n_estimators=567; total time= 2.1min
# [CV] END bootstrap=True, max_depth=23, max_features=sqrt, min_samples_leaf=0.00011996393851034338, n_estimators=567; total time= 1.8min
# [CV] END bootstrap=False, max_depth=199, max_features=sqrt, min_samples_leaf=0.00010952616986110853, n_estimators=28; total time=   9.3s
# [CV] END bootstrap=False, max_depth=199, max_features=sqrt, min_samples_leaf=0.00010952616986110853, n_estimators=28; total time=   9.0s
# [CV] END bootstrap=False, max_depth=199, max_features=sqrt, min_samples_leaf=0.00010952616986110853, n_estimators=28; total time=   8.3s
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=0.00013316128902388574, n_estimators=14; total time=   0.4s
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=0.00013316128902388574, n_estimators=14; total time=   0.4s
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=0.00013316128902388574, n_estimators=14; total time=   0.4s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.00034176919671622405, n_estimators=11; total time=   2.3s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.00034176919671622405, n_estimators=11; total time=   2.2s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.00034176919671622405, n_estimators=11; total time=   2.1s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.000179710324904446, n_estimators=12; total time=   2.7s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.000179710324904446, n_estimators=12; total time=   2.5s
# [CV] END bootstrap=True, max_depth=31, max_features=sqrt, min_samples_leaf=0.000179710324904446, n_estimators=12; total time=   2.5s
# [CV] END bootstrap=False, max_depth=200, max_features=log2, min_samples_leaf=0.002696340107674908, n_estimators=191; total time=  33.6s
# [CV] END bootstrap=False, max_depth=200, max_features=log2, min_samples_leaf=0.002696340107674908, n_estimators=191; total time=  36.0s
# [CV] END bootstrap=True, max_depth=34, max_features=sqrt, min_samples_leaf=0.005307835661434245, n_estimators=1166; total time= 3.2min
# [CV] END bootstrap=True, max_depth=34, max_features=sqrt, min_samples_leaf=0.005307835661434245, n_estimators=1166; total time= 3.3min
# [CV] END bootstrap=True, max_depth=34, max_features=sqrt, min_samples_leaf=0.005307835661434245, n_estimators=1166; total time= 2.9min
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=0.009916637155417315, n_estimators=1892; total time=  49.6s
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=0.009916637155417315, n_estimators=1892; total time=  50.9s
# [CV] END bootstrap=True, max_depth=1, max_features=sqrt, min_samples_leaf=0.009916637155417315, n_estimators=1892; total time=  41.8s
# [CV] END bootstrap=True, max_depth=193, max_features=sqrt, min_samples_leaf=0.0011914916745879788, n_estimators=1998; total time= 6.4min
# [CV] END bootstrap=True, max_depth=193, max_features=sqrt, min_samples_leaf=0.0011914916745879788, n_estimators=1998; total time= 6.6min
# [CV] END bootstrap=True, max_depth=193, max_features=sqrt, min_samples_leaf=0.0011914916745879788, n_estimators=1998; total time= 5.4min
# [CV] END bootstrap=False, max_depth=200, max_features=sqrt, min_samples_leaf=0.0023221124149211104, n_estimators=1954; total time= 9.7min
# [CV] END bootstrap=False, max_depth=200, max_features=sqrt, min_samples_leaf=0.0023221124149211104, n_estimators=1954; total time=10.3min
# [CV] END bootstrap=False, max_depth=200, max_features=sqrt, min_samples_leaf=0.0023221124149211104, n_estimators=1954; total time= 8.4min
# [CV] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=0.009828231894078289, n_estimators=1565; total time= 3.6min
# [CV] END bootstrap=False, max_depth=10, max_features=log2, min_samples_leaf=0.009828231894078289, n_estimators=1565; total time= 3.7min
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=0.005842563302866546, n_estimators=1640; total time= 6.6min
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=0.005842563302866546, n_estimators=1640; total time= 6.8min
# [CV] END bootstrap=False, max_depth=10, max_features=sqrt, min_samples_leaf=0.005842563302866546, n_estimators=1640; total time= 5.9min
# [CV] END bootstrap=True, max_depth=42, max_features=sqrt, min_samples_leaf=0.00010136608061102067, n_estimators=1450; total time= 5.2min
# [CV] END bootstrap=True, max_depth=42, max_features=sqrt, min_samples_leaf=0.00010136608061102067, n_estimators=1450; total time= 5.3min
# [CV] END bootstrap=True, max_depth=42, max_features=sqrt, min_samples_leaf=0.00010136608061102067, n_estimators=1450; total time= 4.6min
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=0.009208297537457222, n_estimators=15; total time=   0.3s
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=0.009208297537457222, n_estimators=15; total time=   0.3s
# [CV] END bootstrap=True, max_depth=195, max_features=sqrt, min_samples_leaf=0.00886382395053588, n_estimators=14; total time=   2.1s
# [CV] END bootstrap=True, max_depth=195, max_features=sqrt, min_samples_leaf=0.00886382395053588, n_estimators=14; total time=   2.5s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, min_samples_leaf=0.005524305838087087, n_estimators=11; total time=   2.2s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, min_samples_leaf=0.005524305838087087, n_estimators=11; total time=   1.8s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, min_samples_leaf=0.005524305838087087, n_estimators=11; total time=   1.7s
# [CV] END bootstrap=False, max_depth=62, max_features=sqrt, min_samples_leaf=0.005398827110843554, n_estimators=10; total time=   3.1s
# [CV] END bootstrap=False, max_depth=62, max_features=sqrt, min_samples_leaf=0.005398827110843554, n_estimators=10; total time=   3.5s
# [CV] END bootstrap=False, max_depth=62, max_features=sqrt, min_samples_leaf=0.005398827110843554, n_estimators=10; total time=   2.8s
# [CV] END bootstrap=False, max_depth=14, max_features=log2, min_samples_leaf=0.00016276726149398857, n_estimators=10; total time=   2.8s
# [CV] END bootstrap=False, max_depth=14, max_features=log2, min_samples_leaf=0.00016276726149398857, n_estimators=10; total time=   2.8s
# [CV] END bootstrap=False, max_depth=48, max_features=sqrt, min_samples_leaf=0.0007198269015019031, n_estimators=31; total time=  11.5s
# [CV] END bootstrap=False, max_depth=48, max_features=sqrt, min_samples_leaf=0.0007198269015019031, n_estimators=31; total time=  10.4s
# [CV] END bootstrap=False, max_depth=48, max_features=sqrt, min_samples_leaf=0.0007198269015019031, n_estimators=31; total time=   9.1s
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=0.00010402038686341951, n_estimators=1932; total time=  54.6s
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=0.00010402038686341951, n_estimators=1932; total time=  47.1s
# [CV] END bootstrap=True, max_depth=37, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 7.6min
# [CV] END bootstrap=True, max_depth=37, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 8.5min
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# [CV] END bootstrap=True, max_depth=37, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 6.6min
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 7.2min
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 7.5min
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits
# Fitting 11 folds for each of 1 candidates, totalling 11 fits

# %% [markdown]
# ## Saving and outputing results

# %%
result_df = pd.DataFrame(param_search.cv_results_)
result_df.insert(0, 'model', str(estimator))
result_df.insert(1, 'held out', held_out)
result_df.insert(2, 'balanced', is_balanced)
result_df.insert(3, 'n_splits', param_search.get_params()['cv'].get_n_splits())
result_df.insert(4, 'feature set', str(feature_types))
display(result_df)
save_results_df_to_file(result_df, f'{search_type}_{name}')
# Out:
#                        model     held out  balanced  n_splits  \
# 0   RandomForestClassifier()  participant      True        11
# 1   RandomForestClassifier()  participant      True        11
# 2   RandomForestClassifier()  participant      True        11
# 3   RandomForestClassifier()  participant      True        11
# 4   RandomForestClassifier()  participant      True        11
# 5   RandomForestClassifier()  participant      True        11
# 6   RandomForestClassifier()  participant      True        11
# 7   RandomForestClassifier()  participant      True        11
# 8   RandomForestClassifier()  participant      True        11
# 9   RandomForestClassifier()  participant      True        11
# 10  RandomForestClassifier()  participant      True        11
# 11  RandomForestClassifier()  participant      True        11
# 12  RandomForestClassifier()  participant      True        11
# 13  RandomForestClassifier()  participant      True        11
# 14  RandomForestClassifier()  participant      True        11
# 15  RandomForestClassifier()  participant      True        11
# 16  RandomForestClassifier()  participant      True        11
# 17  RandomForestClassifier()  participant      True        11
# 18  RandomForestClassifier()  participant      True        11
# 19  RandomForestClassifier()  participant      True        11
# 20  RandomForestClassifier()  participant      True        11
# 21  RandomForestClassifier()  participant      True        11
# 22  RandomForestClassifier()  participant      True        11
# 23  RandomForestClassifier()  participant      True        11
# 24  RandomForestClassifier()  participant      True        11
# 25  RandomForestClassifier()  participant      True        11
# 26  RandomForestClassifier()  participant      True        11
# 27  RandomForestClassifier()  participant      True        11
# 28  RandomForestClassifier()  participant      True        11
# 29  RandomForestClassifier()  participant      True        11
# 30  RandomForestClassifier()  participant      True        11
# 31  RandomForestClassifier()  participant      True        11
# 32  RandomForestClassifier()  participant      True        11
# 33  RandomForestClassifier()  participant      True        11
# 34  RandomForestClassifier()  participant      True        11
# 35  RandomForestClassifier()  participant      True        11
# 36  RandomForestClassifier()  participant      True        11
# 37  RandomForestClassifier()  participant      True        11
# 38  RandomForestClassifier()  participant      True        11
# 39  RandomForestClassifier()  participant      True        11
# 40  RandomForestClassifier()  participant      True        11
# 41  RandomForestClassifier()  participant      True        11
# 42  RandomForestClassifier()  participant      True        11
# 43  RandomForestClassifier()  participant      True        11
# 44  RandomForestClassifier()  participant      True        11
# 45  RandomForestClassifier()  participant      True        11
# 46  RandomForestClassifier()  participant      True        11
# 47  RandomForestClassifier()  participant      True        11
# 48  RandomForestClassifier()  participant      True        11
# 49  RandomForestClassifier()  participant      True        11
#
#                                           feature set  mean_fit_time  \
# 0   {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...     110.273882
# 1   {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...      94.361340
# 2   {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...       5.295284
# 3   {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...       8.293554
# 4   {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...     206.644597
# 5   {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...      90.205621
# 6   {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...      22.392701
# 7   {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...       5.611142
# 8   {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...      14.557095
# 9   {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...      66.046084
# 10  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...      15.643724
# 11  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...      22.852221
# 12  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...       3.711831
# 13  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...     423.692228
# 14  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...       2.720422
# 15  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...     586.605937
# 16  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...      33.178064
# 17  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...      10.457131
# 18  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...      12.693318
# 19  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...       2.279809
# 20  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...     136.713279
# 21  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...      43.004952
# 22  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...       3.149814
# 23  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...       2.534001
# 24  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...     118.621557
# 25  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...       8.852771
# 26  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...       0.388213
# 27  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...       2.213358
# 28  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...       2.513080
# 29  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...      33.176414
# 30  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...     190.840634
# 31  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...      48.650873
# 32  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...     381.460470
# 33  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...     564.981118
# 34  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...     208.698169
# 35  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...     393.651301
# 36  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...     307.373001
# 37  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...       0.256662
# 38  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...       2.214480
# 39  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...       1.964275
# 40  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...       3.266352
# 41  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...       2.386105
# 42  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...      10.495199
# 43  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...      47.410950
# 44  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...     451.128139
# 45  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...     417.962151
# 46  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...      22.171837
# 47  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...       5.433086
# 48  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...      12.180110
# 49  {'MeanFreq', 'SD', 'Min', 'MAD', 'LempelZivEnt...      43.386198
#
#     std_fit_time  mean_score_time  std_score_time param_bootstrap  ...  \
# 0       6.238155         0.069796        0.024088           False  ...
# 1       7.653155         0.155943        0.042127            True  ...
# 2       0.355435         0.006896        0.001699           False  ...
# 3       0.824832         0.019509        0.006250            True  ...
# 4      19.787805         0.204251        0.080056            True  ...
# 5       5.121079         0.135051        0.031244            True  ...
# 6       1.564606         0.038687        0.009999            True  ...
# 7       0.379016         0.010922        0.002793            True  ...
# 8       1.216132         0.014108        0.003469            True  ...
# 9       3.735273         0.038558        0.009985           False  ...
# 10      1.343463         0.023588        0.006041            True  ...
# 11      1.317720         0.024211        0.005678           False  ...
# 12      0.277285         0.005141        0.001071            True  ...
# 13     23.550276         0.391237        0.060770            True  ...
# 14      0.481868         0.005595        0.002319            True  ...
# 15     37.685293         0.346463        0.103499           False  ...
# 16      2.226603         0.025559        0.010143           False  ...
# 17      0.759827         0.012259        0.002930            True  ...
# 18      0.703428         0.037113        0.008129           False  ...
# 19      0.346852         0.009254        0.006064            True  ...
# 20      7.601121         0.080135        0.019430           False  ...
# 21      3.113695         0.190529        0.050063           False  ...
# 22      0.259004         0.004429        0.000979            True  ...
# 23      0.129024         0.003440        0.000791           False  ...
# 24      7.420084         0.101965        0.023681            True  ...
# 25      0.711027         0.006752        0.001478           False  ...
# 26      0.009274         0.003625        0.000554            True  ...
# 27      0.135255         0.003923        0.001004            True  ...
# 28      0.148561         0.004311        0.000784            True  ...
# 29      1.998306         0.034465        0.008678           False  ...
# 30     11.525021         0.181274        0.047577            True  ...
# 31      3.070518         0.189557        0.052215            True  ...
# 32     25.141053         0.357237        0.106130            True  ...
# 33     48.808429         0.360517        0.107262           False  ...
# 34      9.675342         0.241478        0.068879           False  ...
# 35     24.173926         0.283759        0.098307           False  ...
# 36     23.805026         0.268846        0.080362            True  ...
# 37      0.023303         0.003709        0.001235            True  ...
# 38      0.130927         0.005963        0.005227            True  ...
# 39      0.256503         0.005468        0.005169            True  ...
# 40      0.326231         0.003966        0.000695           False  ...
# 41      0.407554         0.005789        0.004988           False  ...
# 42      1.296839         0.007420        0.001572           False  ...
# 43      4.908983         0.228193        0.079410           False  ...
# 44     48.703907         0.355537        0.095561            True  ...
# 45     23.896478         0.360278        0.086624            True  ...
# 46      1.365047         0.023359        0.005930           False  ...
# 47      0.400366         0.005350        0.001280           False  ...
# 48      0.720154         0.019344        0.004981            True  ...
# 49      2.976462         0.039294        0.010324            True  ...
#
#    split4_test_score split5_test_score split6_test_score split7_test_score  \
# 0           0.258609          0.379334          0.255110          0.275064
# 1           0.247130          0.386269          0.079485          0.269923
# 2           0.192438          0.358530          0.258138          0.318766
# 3           0.236327          0.368932          0.102195          0.363325
# 4           0.246455          0.387656          0.249811          0.278492
# 5           0.252532          0.377947          0.179410          0.273350
# 6           0.221472          0.383495          0.089326          0.270780
# 7           0.060770          0.391123          0.180167          0.268209
# 8           0.266712          0.390430          0.181681          0.299057
# 9           0.243754          0.377254          0.224830          0.277635
# 10          0.245105          0.364771          0.111279          0.282776
# 11          0.237002          0.356449          0.202877          0.272494
# 12          0.237002          0.438974          0.246026          0.354756
# 13          0.256583          0.382802          0.272521          0.275921
# 14          0.240378          0.387656          0.363361          0.298201
# 15          0.253207          0.386963          0.268736          0.276778
# 16          0.255908          0.385576          0.249811          0.276778
# 17          0.245780          0.386963          0.044663          0.284490
# 18          0.161377          0.339806          0.106737          0.272494
# 19          0.234301          0.371012          0.056018          0.221080
# 20          0.255233          0.366852          0.289932          0.276778
# 21          0.155300          0.319001          0.105980          0.168809
# 22          0.237002          0.337725          0.267222          0.280206
# 23          0.194463          0.375173          0.208176          0.271637
# 24          0.256583          0.387656          0.281605          0.275921
# 25          0.262660          0.356449          0.236185          0.267352
# 26          0.238352          0.379334          0.151400          0.245930
# 27          0.186361          0.298197          0.345950          0.321337
# 28          0.233626          0.331484          0.214232          0.373608
# 29          0.231600          0.373093          0.169569          0.278492
# 30          0.253207          0.389043          0.232400          0.276778
# 31          0.206617          0.368932          0.101438          0.247644
# 32          0.253207          0.384189          0.257381          0.278492
# 33          0.251182          0.384882          0.254353          0.279349
# 34          0.238352          0.386269          0.093868          0.269066
# 35          0.256583          0.389736          0.242998          0.282776
# 36          0.256583          0.380721          0.284633          0.275921
# 37          0.231600          0.276699          0.127933          0.141388
# 38          0.251857          0.402219          0.059046          0.293059
# 39          0.206617          0.277393          0.093111          0.284490
# 40          0.303174          0.409847          0.148372          0.414739
# 41          0.220122          0.332178          0.161241          0.419023
# 42          0.092505          0.350208          0.233914          0.287061
# 43          0.147873          0.321775          0.103709          0.185090
# 44          0.258609          0.382802          0.281605          0.275921
# 45          0.257934          0.388350          0.280091          0.275921
# 46          0.230925          0.352982          0.227101          0.295630
# 47          0.270763          0.400139          0.146858          0.390746
# 48          0.234976          0.328710          0.126419          0.271637
# 49          0.247806          0.382108          0.280091          0.280206
#
#    split8_test_score  split9_test_score  split10_test_score  mean_test_score  \
# 0           0.383033           0.000000            0.049107         0.238703
# 1           0.322194           0.000000            0.007440         0.215027
# 2           0.340189           0.000857            0.113095         0.224005
# 3           0.262211           0.000000            0.000000         0.232683
# 4           0.324764           0.000000            0.031250         0.236308
# 5           0.331620           0.000000            0.053571         0.231714
# 6           0.277635           0.000000            0.005952         0.216288
# 7           0.272494           0.000000            0.011905         0.211377
# 8           0.348757           0.000000            0.050595         0.248626
# 9           0.329906           0.000000            0.049107         0.236308
# 10          0.269066           0.000000            0.099702         0.243859
# 11          0.369323           0.003428            0.026786         0.237560
# 12          0.376178           0.041131            0.113095         0.258620
# 13          0.365895           0.000000            0.034226         0.243569
# 14          0.275921           0.009426            0.074405         0.223987
# 15          0.427592           0.000000            0.031250         0.246351
# 16          0.357326           0.000000            0.031250         0.248731
# 17          0.355613           0.000000            0.034226         0.237860
# 18          0.245930           0.000000            0.000000         0.205795
# 19          0.274207           0.002571            0.000000         0.198940
# 20          0.373608           0.000000            0.046131         0.244639
# 21          0.245930           0.000000            0.000000         0.211848
# 22          0.358183           0.000000            0.093750         0.265042
# 23          0.313625           0.045416            0.026786         0.226804
# 24          0.416452           0.000000            0.038690         0.244358
# 25          0.276778           0.000000            0.096726         0.237281
# 26          0.245930           0.000857            0.000000         0.242618
# 27          0.305913           0.029991            0.035714         0.242536
# 28          0.311911           0.029991            0.126488         0.234769
# 29          0.320480           0.000000            0.013393         0.223262
# 30          0.353899           0.000000            0.061012         0.254941
# 31          0.245930           0.000000            0.000000         0.208555
# 32          0.321337           0.000000            0.037202         0.241276
# 33          0.319623           0.000000            0.025298         0.239102
# 34          0.311054           0.000000            0.007440         0.218043
# 35          0.304199           0.000000            0.052083         0.233660
# 36          0.373608           0.000000            0.043155         0.245785
# 37          0.245930           0.013710            0.000000         0.181224
# 38          0.314482           0.001714            0.180060         0.233140
# 39          0.245073           0.011997            0.034226         0.201221
# 40          0.330763           0.005998            0.089286         0.245589
# 41          0.357326           0.047986            0.065476         0.241147
# 42          0.342759           0.000000            0.008929         0.222180
# 43          0.245930           0.000857            0.000000         0.212095
# 44          0.380463           0.000000            0.032738         0.241013
# 45          0.372751           0.000000            0.040179         0.244407
# 46          0.321337           0.000000            0.046131         0.230682
# 47          0.296487           0.000857            0.023810         0.230126
# 48          0.375321           0.000000            0.014881         0.215725
# 49          0.347044           0.000000            0.062500         0.240388
#
#     std_test_score  rank_test_score
# 0         0.136718               21
# 1         0.160239               42
# 2         0.123019               35
# 3         0.151029               30
# 4         0.139759               25
# 5         0.135724               31
# 6         0.148409               40
# 7         0.154735               45
# 8         0.149793                5
# 9         0.136015               26
# 10        0.137891               12
# 11        0.126355               23
# 12        0.136386                2
# 13        0.141846               13
# 14        0.107962               36
# 15        0.145293                6
# 16        0.149721                4
# 17        0.165271               22
# 18        0.139275               47
# 19        0.155502               49
# 20        0.139578                9
# 21        0.139903               44
# 22        0.140036                1
# 23        0.128153               34
# 24        0.149078               11
# 25        0.124801               24
# 26        0.149971               14
# 27        0.141789               15
# 28        0.104087               27
# 29        0.145091               37
# 30        0.161055                3
# 31        0.142751               46
# 32        0.145249               16
# 33        0.146638               20
# 34        0.155317               39
# 35        0.142739               28
# 36        0.143321                7
# 37        0.102558               50
# 38        0.142299               29
# 39        0.129481               48
# 40        0.150145                8
# 41        0.115052               17
# 42        0.152457               38
# 43        0.139958               43
# 44        0.141274               18
# 45        0.138856               10
# 46        0.122136               32
# 47        0.160235               33
# 48        0.141494               41
# 49        0.129568               19
#
# [50 rows x 29 columns]
# saving to ../data/results/bayesian_optimization_RandomForest_2024-02-22T16:06:29.csv

# %%
_ = output_model_best_from_results(result_df)
# Out:
# RandomForestClassifier(): max_test_score= 0.2650423567735877, max_std_test_score= 0.14003557522134547
# best params: OrderedDict([('bootstrap', True), ('max_depth', 31), ('max_features', 'sqrt'), ('min_samples_leaf', 0.00032828990339886245), ('n_estimators', 15)])

# %%
feature_types
# Out:
# {'Correlation',
#  'Energy',
#  'FreqKurtosis',
#  'FreqSkewness',
#  'Hurst',
#  'IQR',
#  'LempelZivEntropy',
#  'LyapunovExponent',
#  'MAD',
#  'Max',
#  'MaxFreqInd',
#  'Mean',
#  'MeanFreq',
#  'Min',
#  'SD',
#  'arCoeff'}
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=0.00010402038686341951, n_estimators=1932; total time=  46.1s
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=0.00010402038686341951, n_estimators=1932; total time=  41.7s
# [CV] END bootstrap=True, max_depth=37, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 7.7min
# [CV] END bootstrap=True, max_depth=37, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 8.0min
# [CV] END bootstrap=True, max_depth=37, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 6.2min
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 7.0min
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 7.3min
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 6.2min
# [CV] END bootstrap=False, max_depth=195, max_features=log2, min_samples_leaf=0.00010055974895170814, n_estimators=111; total time=  22.2s
# [CV] END bootstrap=False, max_depth=195, max_features=log2, min_samples_leaf=0.00010055974895170814, n_estimators=111; total time=  23.6s
# [CV] END bootstrap=False, max_depth=195, max_features=log2, min_samples_leaf=0.00010055974895170814, n_estimators=111; total time=  18.5s
# [CV] END bootstrap=False, max_depth=184, max_features=sqrt, min_samples_leaf=0.009739721622459256, n_estimators=23; total time=   5.6s
# [CV] END bootstrap=False, max_depth=184, max_features=sqrt, min_samples_leaf=0.009739721622459256, n_estimators=23; total time=   5.5s
# [CV] END bootstrap=False, max_depth=184, max_features=sqrt, min_samples_leaf=0.009739721622459256, n_estimators=23; total time=   4.4s
# [CV] END bootstrap=True, max_depth=199, max_features=log2, min_samples_leaf=0.0001012659988695986, n_estimators=91; total time=  12.2s
# [CV] END bootstrap=True, max_depth=199, max_features=log2, min_samples_leaf=0.0001012659988695986, n_estimators=91; total time=  13.2s
# [CV] END bootstrap=True, max_depth=199, max_features=log2, min_samples_leaf=0.0001012659988695986, n_estimators=91; total time=  11.3s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=210; total time=  45.2s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=210; total time=  46.8s
# [CV] END bootstrap=False, max_depth=195, max_features=log2, min_samples_leaf=0.00010055974895170814, n_estimators=111; total time=  22.5s
# [CV] END bootstrap=False, max_depth=195, max_features=log2, min_samples_leaf=0.00010055974895170814, n_estimators=111; total time=  23.9s
# [CV] END bootstrap=False, max_depth=184, max_features=sqrt, min_samples_leaf=0.009739721622459256, n_estimators=23; total time=   5.5s
# [CV] END bootstrap=False, max_depth=184, max_features=sqrt, min_samples_leaf=0.009739721622459256, n_estimators=23; total time=   5.8s
# [CV] END bootstrap=False, max_depth=184, max_features=sqrt, min_samples_leaf=0.009739721622459256, n_estimators=23; total time=   4.9s
# [CV] END bootstrap=True, max_depth=199, max_features=log2, min_samples_leaf=0.0001012659988695986, n_estimators=91; total time=  12.3s
# [CV] END bootstrap=True, max_depth=199, max_features=log2, min_samples_leaf=0.0001012659988695986, n_estimators=91; total time=  12.5s
# [CV] END bootstrap=True, max_depth=199, max_features=log2, min_samples_leaf=0.0001012659988695986, n_estimators=91; total time=  10.8s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=210; total time=  43.9s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=210; total time=  44.1s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=210; total time=  35.8s
# [CV] END bootstrap=True, max_depth=42, max_features=sqrt, min_samples_leaf=0.00010136608061102067, n_estimators=1450; total time= 5.4min
# [CV] END bootstrap=True, max_depth=42, max_features=sqrt, min_samples_leaf=0.00010136608061102067, n_estimators=1450; total time= 5.2min
# [CV] END bootstrap=True, max_depth=42, max_features=sqrt, min_samples_leaf=0.00010136608061102067, n_estimators=1450; total time= 4.3min
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=0.009208297537457222, n_estimators=15; total time=   0.3s
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=0.009208297537457222, n_estimators=15; total time=   0.3s
# [CV] END bootstrap=True, max_depth=1, max_features=log2, min_samples_leaf=0.009208297537457222, n_estimators=15; total time=   0.2s
# [CV] END bootstrap=True, max_depth=195, max_features=sqrt, min_samples_leaf=0.00886382395053588, n_estimators=14; total time=   2.2s
# [CV] END bootstrap=True, max_depth=195, max_features=sqrt, min_samples_leaf=0.00886382395053588, n_estimators=14; total time=   2.1s
# [CV] END bootstrap=True, max_depth=195, max_features=sqrt, min_samples_leaf=0.00886382395053588, n_estimators=14; total time=   2.1s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, min_samples_leaf=0.005524305838087087, n_estimators=11; total time=   2.1s
# [CV] END bootstrap=True, max_depth=8, max_features=sqrt, min_samples_leaf=0.005524305838087087, n_estimators=11; total time=   2.3s
# [CV] END bootstrap=False, max_depth=62, max_features=sqrt, min_samples_leaf=0.005398827110843554, n_estimators=10; total time=   3.1s
# [CV] END bootstrap=False, max_depth=62, max_features=sqrt, min_samples_leaf=0.005398827110843554, n_estimators=10; total time=   3.6s
# [CV] END bootstrap=False, max_depth=62, max_features=sqrt, min_samples_leaf=0.005398827110843554, n_estimators=10; total time=   2.8s
# [CV] END bootstrap=False, max_depth=14, max_features=log2, min_samples_leaf=0.00016276726149398857, n_estimators=10; total time=   2.6s
# [CV] END bootstrap=False, max_depth=14, max_features=log2, min_samples_leaf=0.00016276726149398857, n_estimators=10; total time=   2.3s
# [CV] END bootstrap=False, max_depth=14, max_features=log2, min_samples_leaf=0.00016276726149398857, n_estimators=10; total time=   1.9s
# [CV] END bootstrap=False, max_depth=48, max_features=sqrt, min_samples_leaf=0.0007198269015019031, n_estimators=31; total time=  11.9s
# [CV] END bootstrap=False, max_depth=48, max_features=sqrt, min_samples_leaf=0.0007198269015019031, n_estimators=31; total time=  10.5s
# [CV] END bootstrap=False, max_depth=48, max_features=sqrt, min_samples_leaf=0.0007198269015019031, n_estimators=31; total time=   8.1s
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=0.00010402038686341951, n_estimators=1932; total time=  52.5s
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=0.00010402038686341951, n_estimators=1932; total time=  45.8s
# [CV] END bootstrap=False, max_depth=1, max_features=log2, min_samples_leaf=0.00010402038686341951, n_estimators=1932; total time=  38.8s
# [CV] END bootstrap=True, max_depth=37, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 7.5min
# [CV] END bootstrap=True, max_depth=37, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 8.2min
# [CV] END bootstrap=True, max_depth=37, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 6.1min
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 7.0min
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 7.4min
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 6.5min
# [CV] END bootstrap=False, max_depth=195, max_features=log2, min_samples_leaf=0.00010055974895170814, n_estimators=111; total time=  22.6s
# [CV] END bootstrap=False, max_depth=195, max_features=log2, min_samples_leaf=0.00010055974895170814, n_estimators=111; total time=  22.9s
# [CV] END bootstrap=False, max_depth=195, max_features=log2, min_samples_leaf=0.00010055974895170814, n_estimators=111; total time=  21.1s
# [CV] END bootstrap=False, max_depth=184, max_features=sqrt, min_samples_leaf=0.009739721622459256, n_estimators=23; total time=   5.6s
# [CV] END bootstrap=False, max_depth=184, max_features=sqrt, min_samples_leaf=0.009739721622459256, n_estimators=23; total time=   5.8s
# [CV] END bootstrap=True, max_depth=199, max_features=log2, min_samples_leaf=0.0001012659988695986, n_estimators=91; total time=  12.0s
# [CV] END bootstrap=True, max_depth=199, max_features=log2, min_samples_leaf=0.0001012659988695986, n_estimators=91; total time=  12.5s
# [CV] END bootstrap=True, max_depth=199, max_features=log2, min_samples_leaf=0.0001012659988695986, n_estimators=91; total time=  11.6s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=210; total time=  45.2s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=210; total time=  43.5s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=210; total time=  40.5s
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 7.1min
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 7.0min
# [CV] END bootstrap=True, max_depth=40, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=2000; total time= 6.5min
# [CV] END bootstrap=False, max_depth=195, max_features=log2, min_samples_leaf=0.00010055974895170814, n_estimators=111; total time=  22.2s
# [CV] END bootstrap=False, max_depth=195, max_features=log2, min_samples_leaf=0.00010055974895170814, n_estimators=111; total time=  22.8s
# [CV] END bootstrap=False, max_depth=195, max_features=log2, min_samples_leaf=0.00010055974895170814, n_estimators=111; total time=  21.9s
# [CV] END bootstrap=False, max_depth=184, max_features=sqrt, min_samples_leaf=0.009739721622459256, n_estimators=23; total time=   5.5s
# [CV] END bootstrap=False, max_depth=184, max_features=sqrt, min_samples_leaf=0.009739721622459256, n_estimators=23; total time=   5.9s
# [CV] END bootstrap=False, max_depth=184, max_features=sqrt, min_samples_leaf=0.009739721622459256, n_estimators=23; total time=   5.3s
# [CV] END bootstrap=True, max_depth=199, max_features=log2, min_samples_leaf=0.0001012659988695986, n_estimators=91; total time=  12.7s
# [CV] END bootstrap=True, max_depth=199, max_features=log2, min_samples_leaf=0.0001012659988695986, n_estimators=91; total time=  13.3s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=210; total time=  44.6s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=210; total time=  46.3s
# [CV] END bootstrap=True, max_depth=50, max_features=sqrt, min_samples_leaf=0.0001, n_estimators=210; total time=  41.7s

# %%
list(feature_types)
# Out:
# ['MeanFreq',
#  'SD',
#  'Min',
#  'MAD',
#  'LempelZivEntropy',
#  'MaxFreqInd',
#  'Energy',
#  'Mean',
#  'Max',
#  'Correlation',
#  'LyapunovExponent',
#  'FreqSkewness',
#  'FreqKurtosis',
#  'Hurst',
#  'IQR',
#  'arCoeff']

# %%
param_search
# Out:
# BayesSearchCV(cv=GroupKFold(n_splits=11), estimator=RandomForestClassifier(),
#               n_jobs=-1, random_state=42,
#               search_spaces={'bootstrap': Categorical(categories=(True, False), prior=None),
#                              'max_depth': Integer(low=1, high=200, prior='log-uniform', transform='normalize'),
#                              'max_features': Categorical(categories=('log2', 'sqrt'), prior=None),
#                              'min_samples_leaf': Real(low=0.0001, high=0.01, prior='log-uniform', transform='normalize'),
#                              'n_estimators': Integer(low=10, high=2000, prior='log-uniform', transform='normalize')},
#               verbose=2)

# %%
param_search.get_params()
# Out:
# {'cv': GroupKFold(n_splits=11),
#  'error_score': 'raise',
#  'estimator__bootstrap': True,
#  'estimator__ccp_alpha': 0.0,
#  'estimator__class_weight': None,
#  'estimator__criterion': 'gini',
#  'estimator__max_depth': None,
#  'estimator__max_features': 'sqrt',
#  'estimator__max_leaf_nodes': None,
#  'estimator__max_samples': None,
#  'estimator__min_impurity_decrease': 0.0,
#  'estimator__min_samples_leaf': 1,
#  'estimator__min_samples_split': 2,
#  'estimator__min_weight_fraction_leaf': 0.0,
#  'estimator__monotonic_cst': None,
#  'estimator__n_estimators': 100,
#  'estimator__n_jobs': None,
#  'estimator__oob_score': False,
#  'estimator__random_state': None,
#  'estimator__verbose': 0,
#  'estimator__warm_start': False,
#  'estimator': RandomForestClassifier(),
#  'fit_params': None,
#  'iid': 'deprecated',
#  'n_iter': 50,
#  'n_jobs': -1,
#  'n_points': 1,
#  'optimizer_kwargs': None,
#  'pre_dispatch': '2*n_jobs',
#  'random_state': 42,
#  'refit': True,
#  'return_train_score': False,
#  'scoring': None,
#  'search_spaces': {'n_estimators': Integer(low=10, high=2000, prior='log-uniform', transform='normalize'),
#   'max_features': Categorical(categories=('log2', 'sqrt'), prior=None),
#   'max_depth': Integer(low=1, high=200, prior='log-uniform', transform='normalize'),
#   'min_samples_leaf': Real(low=0.0001, high=0.01, prior='log-uniform', transform='normalize'),
#   'bootstrap': Categorical(categories=(True, False), prior=None)},
#  'verbose': 2}

# %%
# Out:
# 11

# %%
is_balanced = True
